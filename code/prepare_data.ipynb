# %%
import os
import json
from glob import glob

# %% [markdown]
# ## json_file 리스트 불러오기

# %%
file_list = glob('../data/KBN_data/*')
file_list.sort()
file_list
# Out:
# ['../data/KBN_data/wikipedia_0001.json',
#  '../data/KBN_data/wikipedia_0002.json',
#  '../data/KBN_data/wikipedia_0003.json',
#  '../data/KBN_data/wikipedia_0004.json',
#  '../data/KBN_data/wikipedia_0005.json',
#  '../data/KBN_data/wikipedia_0006.json',
#  '../data/KBN_data/wikipedia_0007.json',
#  '../data/KBN_data/wikipedia_0008.json',
#  '../data/KBN_data/wikipedia_0009.json',
#  '../data/KBN_data/wikipedia_0010.json',
#  '../data/KBN_data/wikipedia_0011.json',
#  '../data/KBN_data/wikipedia_0012.json',
#  '../data/KBN_data/wikipedia_0013.json',
#  '../data/KBN_data/wikipedia_0014.json',
#  '../data/KBN_data/wikipedia_0015.json',
#  '../data/KBN_data/wikipedia_0016.json',
#  '../data/KBN_data/wikipedia_0017.json',
#  '../data/KBN_data/wikipedia_0018.json',
#  '../data/KBN_data/wikipedia_0019.json',
#  '../data/KBN_data/wikipedia_0020.json',
#  '../data/KBN_data/wikipedia_0021.json',
#  '../data/KBN_data/wikipedia_0022.json',
#  '../data/KBN_data/wikipedia_0023.json',
#  '../data/KBN_data/wikipedia_0024.json',
#  '../data/KBN_data/wikipedia_0025.json',
#  '../data/KBN_data/wikipedia_0026.json',
#  '../data/KBN_data/wikipedia_0027.json',
#  '../data/KBN_data/wikipedia_0028.json',
#  '../data/KBN_data/wikipedia_0029.json',
#  '../data/KBN_data/wikipedia_0030.json',
#  '../data/KBN_data/wikipedia_0031.json',
#  '../data/KBN_data/wikipedia_0032.json',
#  '../data/KBN_data/wikipedia_0033.json',
#  '../data/KBN_data/wikipedia_0034.json',
#  '../data/KBN_data/wikipedia_0035.json',
#  '../data/KBN_data/wikipedia_0036.json',
#  '../data/KBN_data/wikipedia_0037.json',
#  '../data/KBN_data/wikipedia_0038.json',
#  '../data/KBN_data/wikipedia_0039.json',
#  '../data/KBN_data/wikipedia_0040.json',
#  '../data/KBN_data/wikipedia_0041.json',
#  '../data/KBN_data/wikipedia_0042.json',
#  '../data/KBN_data/wikipedia_0043.json',
#  '../data/KBN_data/wikipedia_0044.json',
#  '../data/KBN_data/wikipedia_0045.json',
#  '../data/KBN_data/wikipedia_0046.json',
#  '../data/KBN_data/wikipedia_0047.json',
#  '../data/KBN_data/wikipedia_0048.json',
#  '../data/KBN_data/wikipedia_0049.json',
#  '../data/KBN_data/wikipedia_0050.json',
#  '../data/KBN_data/wikipedia_0051.json',
#  '../data/KBN_data/wikipedia_0052.json',
#  '../data/KBN_data/wikipedia_0053.json',
#  '../data/KBN_data/wikipedia_0054.json',
#  '../data/KBN_data/wikipedia_0055.json',
#  '../data/KBN_data/wikipedia_0056.json',
#  '../data/KBN_data/wikipedia_0057.json',
#  '../data/KBN_data/wikipedia_0058.json',
#  '../data/KBN_data/wikipedia_0059.json',
#  '../data/KBN_data/wikipedia_0060.json',
#  '../data/KBN_data/wikipedia_0061.json',
#  '../data/KBN_data/wikipedia_0126.json',
#  '../data/KBN_data/wikipedia_0127.json',
#  '../data/KBN_data/wikipedia_0128.json',
#  '../data/KBN_data/wikipedia_0129.json',
#  '../data/KBN_data/wikipedia_0130.json',
#  '../data/KBN_data/wikipedia_0131.json',
#  '../data/KBN_data/wikipedia_0132.json',
#  '../data/KBN_data/wikipedia_0133.json',
#  '../data/KBN_data/wikipedia_0134.json',
#  '../data/KBN_data/wikipedia_0135.json',
#  '../data/KBN_data/wikipedia_0136.json',
#  '../data/KBN_data/wikipedia_0137.json',
#  '../data/KBN_data/wikipedia_0138.json',
#  '../data/KBN_data/wikipedia_0139.json',
#  '../data/KBN_data/wikipedia_0140.json',
#  '../data/KBN_data/wikipedia_0141.json',
#  '../data/KBN_data/wikipedia_0142.json',
#  '../data/KBN_data/wikipedia_0143.json',
#  '../data/KBN_data/wikipedia_0144.json',
#  '../data/KBN_data/wikipedia_0145.json',
#  '../data/KBN_data/wikipedia_0146.json',
#  '../data/KBN_data/wikipedia_0147.json',
#  '../data/KBN_data/wikipedia_0148.json',
#  '../data/KBN_data/wikipedia_0149.json',
#  '../data/KBN_data/wikipedia_0150.json',
#  '../data/KBN_data/wikipedia_0151.json',
#  '../data/KBN_data/wikipedia_0152.json',
#  '../data/KBN_data/wikipedia_0153.json',
#  '../data/KBN_data/wikipedia_0154.json',
#  '../data/KBN_data/wikipedia_0155.json',
#  '../data/KBN_data/wikipedia_0156.json',
#  '../data/KBN_data/wikipedia_0157.json',
#  '../data/KBN_data/wikipedia_0158.json',
#  '../data/KBN_data/wikipedia_0159.json',
#  '../data/KBN_data/wikipedia_0160.json',
#  '../data/KBN_data/wikipedia_0161.json',
#  '../data/KBN_data/wikipedia_0162.json',
#  '../data/KBN_data/wikipedia_0163.json',
#  '../data/KBN_data/wikipedia_0164.json',
#  '../data/KBN_data/wikipedia_0165.json',
#  '../data/KBN_data/wikipedia_0166.json',
#  '../data/KBN_data/wikipedia_0167.json',
#  '../data/KBN_data/wikipedia_0168.json',
#  '../data/KBN_data/wikipedia_0169.json',
#  '../data/KBN_data/wikipedia_0170.json',
#  '../data/KBN_data/wikipedia_0171.json',
#  '../data/KBN_data/wikipedia_0172.json',
#  '../data/KBN_data/wikipedia_0173.json',
#  '../data/KBN_data/wikipedia_0174.json',
#  '../data/KBN_data/wikipedia_0175.json',
#  '../data/KBN_data/wikipedia_0176.json',
#  '../data/KBN_data/wikipedia_0177.json',
#  '../data/KBN_data/wikipedia_0178.json',
#  '../data/KBN_data/wikipedia_0179.json',
#  '../data/KBN_data/wikipedia_0180.json',
#  '../data/KBN_data/wikipedia_0181.json',
#  '../data/KBN_data/wikipedia_0182.json',
#  '../data/KBN_data/wikipedia_0183.json',
#  '../data/KBN_data/wikipedia_0184.json',
#  '../data/KBN_data/wikipedia_0185.json',
#  '../data/KBN_data/wikipedia_0186.json',
#  '../data/KBN_data/wikipedia_0187.json',
#  '../data/KBN_data/wikipedia_0188.json',
#  '../data/KBN_data/wikipedia_0189.json',
#  '../data/KBN_data/wikipedia_0190.json',
#  '../data/KBN_data/wikipedia_0191.json',
#  '../data/KBN_data/wikipedia_0192.json',
#  '../data/KBN_data/wikipedia_0193.json',
#  '../data/KBN_data/wikipedia_0194.json',
#  '../data/KBN_data/wikipedia_0195.json',
#  '../data/KBN_data/wikipedia_0196.json',
#  '../data/KBN_data/wikipedia_0197.json',
#  '../data/KBN_data/wikipedia_0198.json',
#  '../data/KBN_data/wikipedia_0199.json',
#  '../data/KBN_data/wikipedia_0200.json',
#  '../data/KBN_data/wikipedia_0201.json',
#  '../data/KBN_data/wikipedia_0202.json',
#  '../data/KBN_data/wikipedia_0203.json',
#  '../data/KBN_data/wikipedia_0204.json',
#  '../data/KBN_data/wikipedia_0205.json',
#  '../data/KBN_data/wikipedia_0206.json',
#  '../data/KBN_data/wikipedia_0207.json',
#  '../data/KBN_data/wikipedia_0208.json',
#  '../data/KBN_data/wikipedia_0209.json',
#  '../data/KBN_data/wikipedia_0210.json',
#  '../data/KBN_data/wikipedia_0211.json',
#  '../data/KBN_data/wikipedia_0212.json',
#  '../data/KBN_data/wikipedia_0213.json',
#  '../data/KBN_data/wikipedia_0214.json',
#  '../data/KBN_data/wikipedia_0215.json',
#  '../data/KBN_data/wikipedia_0216.json',
#  '../data/KBN_data/wikipedia_0217.json',
#  '../data/KBN_data/wikipedia_0218.json',
#  '../data/KBN_data/wikipedia_0219.json',
#  '../data/KBN_data/wikipedia_0220.json',
#  '../data/KBN_data/wikipedia_0221.json',
#  '../data/KBN_data/wikipedia_0222.json',
#  '../data/KBN_data/wikipedia_0223.json',
#  '../data/KBN_data/wikipedia_0224.json',
#  '../data/KBN_data/wikipedia_0225.json',
#  '../data/KBN_data/wikipedia_0226.json',
#  '../data/KBN_data/wikipedia_0227.json',
#  '../data/KBN_data/wikipedia_0228.json',
#  '../data/KBN_data/wikipedia_0229.json',
#  '../data/KBN_data/wikipedia_0230.json',
#  '../data/KBN_data/wikipedia_0231.json',
#  '../data/KBN_data/wikipedia_0232.json',
#  '../data/KBN_data/wikipedia_0233.json',
#  '../data/KBN_data/wikipedia_0234.json',
#  '../data/KBN_data/wikipedia_0235.json',
#  '../data/KBN_data/wikipedia_0236.json',
#  '../data/KBN_data/wikipedia_0237.json',
#  '../data/KBN_data/wikipedia_0238.json',
#  '../data/KBN_data/wikipedia_0239.json',
#  '../data/KBN_data/wikipedia_0240.json',
#  '../data/KBN_data/wikipedia_0241.json',
#  '../data/KBN_data/wikipedia_0242.json',
#  '../data/KBN_data/wikipedia_0243.json',
#  '../data/KBN_data/wikipedia_0244.json',
#  '../data/KBN_data/wikipedia_0245.json',
#  '../data/KBN_data/wikipedia_0246.json',
#  '../data/KBN_data/wikipedia_0247.json',
#  '../data/KBN_data/wikipedia_0248.json',
#  '../data/KBN_data/wikipedia_0249.json',
#  '../data/KBN_data/wikipedia_0250.json',
#  '../data/KBN_data/wikipedia_0251.json',
#  '../data/KBN_data/wikipedia_0252.json',
#  '../data/KBN_data/wikipedia_0253.json',
#  '../data/KBN_data/wikipedia_0254.json',
#  '../data/KBN_data/wikipedia_0384.json',
#  '../data/KBN_data/wikipedia_0385.json',
#  '../data/KBN_data/wikipedia_0386.json',
#  '../data/KBN_data/wikipedia_0387.json',
#  '../data/KBN_data/wikipedia_0388.json',
#  '../data/KBN_data/wikipedia_0389.json',
#  '../data/KBN_data/wikipedia_0390.json',
#  '../data/KBN_data/wikipedia_0391.json',
#  '../data/KBN_data/wikipedia_0392.json',
#  '../data/KBN_data/wikipedia_0393.json',
#  '../data/KBN_data/wikipedia_0394.json',
#  '../data/KBN_data/wikipedia_0395.json',
#  '../data/KBN_data/wikipedia_0396.json',
#  '../data/KBN_data/wikipedia_0397.json',
#  '../data/KBN_data/wikipedia_0398.json',
#  '../data/KBN_data/wikipedia_0399.json',
#  '../data/KBN_data/wikipedia_0400.json',
#  '../data/KBN_data/wikipedia_0401.json',
#  '../data/KBN_data/wikipedia_0402.json',
#  '../data/KBN_data/wikipedia_0403.json',
#  '../data/KBN_data/wikipedia_0404.json',
#  '../data/KBN_data/wikipedia_0405.json',
#  '../data/KBN_data/wikipedia_0406.json',
#  '../data/KBN_data/wikipedia_0407.json',
#  '../data/KBN_data/wikipedia_0408.json',
#  '../data/KBN_data/wikipedia_0409.json',
#  '../data/KBN_data/wikipedia_0410.json']

# %% [markdown]
# ## 각 json file의 data 변형

# %%
def modify_data(json_file):
    """ 전체 wikipedia_XXXX.json 파일의 data 내용 수정하는 함수.

    Original data example:
        {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
        'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
        'subject': '제임스 얼',
        'subject_tag': 'PS',
        'subject_pos': [0, 5],
        'object': '카터 주니어',
        'object_tag': 'PS',
        'object_pos': [10, 16],
        'relation': 'successor',
        'description': '항목 주제의 후임자',
        'confidence': 0.8254553079605103}

    Modified data example:
        {'file_name': 'wikipedia_0001.json',
        'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
        'subj': {'name': '제임스 얼',
                'pos': [0, 5],
                'type': 'PS'},
        'obj': {'name': '카터 주니어',
                'pos': [10, 16],
                'type': 'PS'},
        'relation': 'successor',
        'description': '항목 주제의 후임자',
        'confidence': 0.8254553079605103}
    """
    pass

# %%
def modify_data(input_filepath):
    modified_data = []
    # filename = "wikipedia_XXXX.json"
    filename = input_filepath[-19:]

    # original data parsing + modify data
    with open(input_filepath, 'r') as f:
        json_data = json.load(f)
        for data in json_data:
            tmp_dict = dict()

            tmp_dict["file_name"] = "/data/modified_KBN_data/" + data["file_name"][-19:] # ../data/modified_KBN_data/wikipedia_XXXX.json
    
            tmp_dict["sentence"] = data["sentence"] 
            
            tmp_dict["subj"] = dict()
            tmp_dict["subj"]["name"] = data["subject"]
            tmp_dict["subj"]["pos"] = data["subject_pos"]
            tmp_dict["subj"]["type"] = data["subject_tag"]
            
            tmp_dict["obj"] = dict()
            tmp_dict["obj"]["name"] = data["object"]
            tmp_dict["obj"]["pos"] = data["object_pos"]
            tmp_dict["obj"]["type"] = data["object_tag"]

            tmp_dict["description"] = data["description"]
            tmp_dict["confidence"] = data["confidence"]
            
            modified_data.append(tmp_dict)
    
    # modified data to json file
    with open(os.path.join("../data/modified_KBN_data", filename), 'w') as f:
        json.dump(modified_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# ## modify data example

# %%
file_example = file_list[0]
file_example
# Out:
# '../data/KBN_data/wikipedia_0001.json'

# %% [markdown]
# ### 예시 데이터 형식

# %%
with open(file_example, 'r') as f:
    json_data = json.load(f)
json_data
# Out:
# [{'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subject': '제임스 얼',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 5],
#   'object': '카터 주니어',
#   'object_tag': 'PS',
#   'object_pos': [10, 16],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8254553079605103},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subject': '제임스 얼',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 5],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [44, 46],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5040757060050964},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subject': '카터 주니어',
#   'subject_tag': 'PS',
#   'subject_pos': [10, 16],
#   'object': '제임스 얼',
#   'object_tag': 'PS',
#   'object_pos': [0, 5],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7290757298469543},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subject': '카터 주니어',
#   'subject_tag': 'PS',
#   'subject_pos': [10, 16],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [44, 46],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.605682373046875},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subject': '민주당',
#   'subject_tag': 'OG',
#   'subject_pos': [37, 40],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [44, 46],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.8298603892326355},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subject': '섬터 카운티',
#   'subject_tag': 'LC',
#   'subject_pos': [12, 18],
#   'object': '조지아주',
#   'object_tag': 'LC',
#   'object_pos': [7, 11],
#   'relation': 'region',
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.776265561580658},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subject': '플레인스',
#   'subject_tag': 'LC',
#   'subject_pos': [19, 23],
#   'object': '조지아주',
#   'object_tag': 'LC',
#   'object_pos': [7, 11],
#   'relation': 'region',
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7227185368537903},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1953년 미국 해군 대위로 예편하였고 이후 땅콩·면화 등을 가꿔 많은 돈을 벌었다.',
#   'subject': '해군',
#   'subject_tag': 'OG',
#   'subject_pos': [9, 11],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [6, 8],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.9773654937744141},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subject': '조지아',
#   'subject_tag': 'LC',
#   'subject_pos': [63, 66],
#   'object': '조지아 주',
#   'object_tag': 'LC',
#   'object_pos': [6, 11],
#   'relation': 'region',
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7467160820960999},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subject': '조지아',
#   'subject_tag': 'LC',
#   'subject_pos': [88, 91],
#   'object': '조지아 주',
#   'object_tag': 'LC',
#   'object_pos': [6, 11],
#   'relation': 'region',
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.735164999961853},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대통령이 되기 전 조지아주 상원의원을 두번 연임했으며, 1971년부터 1975년까지 조지아 지사로 근무했다.',
#   'subject': '조지아',
#   'subject_tag': 'LC',
#   'subject_pos': [47, 50],
#   'object': '조지아주',
#   'object_tag': 'LC',
#   'object_pos': [10, 14],
#   'relation': 'region',
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7667058110237122},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '이집트',
#   'object_tag': 'LC',
#   'object_pos': [4, 7],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6622843146324158},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '이스라엘',
#   'object_tag': 'LC',
#   'object_pos': [9, 13],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7659438848495483},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '안와르 사다트',
#   'object_tag': 'PS',
#   'object_pos': [31, 38],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7613891363143921},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '메나헴 베긴',
#   'object_tag': 'PS',
#   'object_pos': [44, 50],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6384792327880859},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '안와르 사다트',
#   'subject_tag': 'PS',
#   'subject_pos': [31, 38],
#   'object': '카터',
#   'object_tag': 'PS',
#   'object_pos': [0, 2],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7651193141937256},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '안와르 사다트',
#   'subject_tag': 'PS',
#   'subject_pos': [31, 38],
#   'object': '이집트',
#   'object_tag': 'LC',
#   'object_pos': [4, 7],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.522010087966919},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '안와르 사다트',
#   'subject_tag': 'PS',
#   'subject_pos': [31, 38],
#   'object': '이스라엘',
#   'object_tag': 'LC',
#   'object_pos': [9, 13],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6861956715583801},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '안와르 사다트',
#   'subject_tag': 'PS',
#   'subject_pos': [31, 38],
#   'object': '메나헴 베긴',
#   'object_tag': 'PS',
#   'object_pos': [44, 50],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5805528163909912},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '메나헴 베긴',
#   'subject_tag': 'PS',
#   'subject_pos': [44, 50],
#   'object': '카터',
#   'object_tag': 'PS',
#   'object_pos': [0, 2],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7331639528274536},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '메나헴 베긴',
#   'subject_tag': 'PS',
#   'subject_pos': [44, 50],
#   'object': '이집트',
#   'object_tag': 'LC',
#   'object_pos': [4, 7],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.619739294052124},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subject': '메나헴 베긴',
#   'subject_tag': 'PS',
#   'subject_pos': [44, 50],
#   'object': '이스라엘',
#   'object_tag': 'LC',
#   'object_pos': [9, 13],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7720767855644226},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그러나 이것은 공화당과 미국의 유대인 단체의 반발을 일으켰다.',
#   'subject': '공화당',
#   'subject_tag': 'OG',
#   'subject_pos': [8, 11],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [13, 15],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7262453436851501},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 1970년대 후반 당시 대한민국 등 인권 후진국의 국민들의 인권을 지키기 위해 노력했으며, 취임 이후 계속해서 도덕정치를 내세웠다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '대한민국',
#   'object_tag': 'LC',
#   'object_pos': [17, 21],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6086249947547913},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '지미 카터는 대한민국과의 관계에서도 중요한 영향을 미쳤던 대통령 중 하나다.',
#   'subject': '지미 카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 5],
#   'object': '대한민국',
#   'object_tag': 'LC',
#   'object_pos': [7, 11],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5950901508331299},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '인권 문제와 주한미군 철수 문제로 한때 한미 관계가 불편하기도 했다.',
#   'subject': '주한미군',
#   'subject_tag': 'OG',
#   'subject_pos': [7, 11],
#   'object': '한',
#   'object_tag': 'LC',
#   'object_pos': [22, 23],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.8219428062438965},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '인권 문제와 주한미군 철수 문제로 한때 한미 관계가 불편하기도 했다.',
#   'subject': '주한미군',
#   'subject_tag': 'OG',
#   'subject_pos': [7, 11],
#   'object': '미',
#   'object_tag': 'LC',
#   'object_pos': [23, 24],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.8799412250518799},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subject': '한미연합사',
#   'subject_tag': 'OG',
#   'subject_pos': [27, 32],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [15, 17],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7299146056175232},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subject': '주한미군',
#   'subject_tag': 'OG',
#   'subject_pos': [57, 61],
#   'object': '대한민국',
#   'object_tag': 'LC',
#   'object_pos': [6, 10],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.674068808555603},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subject': '주한미군',
#   'subject_tag': 'OG',
#   'subject_pos': [57, 61],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [15, 17],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.8647246956825256},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '10월 26일, 박정희 대통령이 김재규 중앙정보부장에 의해 살해된 것에 대해 그는 이 사건으로 큰 충격을 받았으며, 사이러스 밴스 국무장관을 조문사절로 파견했다.',
#   'subject': '박정희',
#   'subject_tag': 'PS',
#   'subject_pos': [9, 12],
#   'object': '김재규',
#   'object_tag': 'PS',
#   'object_pos': [18, 21],
#   'relation': 'vicePresident',
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5391024947166443},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '12·12 군사 반란과 5.17 쿠데타에 대해 초기에는 강하게 비난했으나, 미국 정부가 신군부를 설득하는데, 한계가 있었고 결국 묵인하는 듯한 태도를 보이게 됐다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [45, 47],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [42, 44],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.8037638664245605},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [14, 16],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5240483283996582},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '코소보',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.60670006275177},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [44, 46],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5123910307884216},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [110, 112],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5621735453605652},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [4, 6],
#   'object': '코소보',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5996441841125488},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [4, 6],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [110, 112],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5718235969543457},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '세드라스',
#   'subject_tag': 'PS',
#   'subject_pos': [30, 34],
#   'object': '하마스',
#   'object_tag': 'PS',
#   'object_pos': [47, 50],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6418309211730957},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '세드라스',
#   'subject_tag': 'PS',
#   'subject_pos': [30, 34],
#   'object': '보스니아',
#   'object_tag': 'LC',
#   'object_pos': [52, 56],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5473065972328186},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '하마스',
#   'subject_tag': 'PS',
#   'subject_pos': [47, 50],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [16, 18],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6758976578712463},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '하마스',
#   'subject_tag': 'PS',
#   'subject_pos': [47, 50],
#   'object': '아이티',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.655730664730072},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '하마스',
#   'subject_tag': 'PS',
#   'subject_pos': [47, 50],
#   'object': '보스니아',
#   'object_tag': 'LC',
#   'object_pos': [52, 56],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6870269179344177},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '미국',
#   'subject_tag': 'OG',
#   'subject_pos': [70, 72],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [16, 18],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6317636966705322},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '미국',
#   'subject_tag': 'OG',
#   'subject_pos': [70, 72],
#   'object': '아이티',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7050158381462097},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '미국',
#   'subject_tag': 'OG',
#   'subject_pos': [70, 72],
#   'object': '보스니아',
#   'object_tag': 'LC',
#   'object_pos': [52, 56],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6846438646316528},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [73, 75],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [16, 18],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7641459703445435},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [73, 75],
#   'object': '아이티',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7563214898109436},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [73, 75],
#   'object': '팔레인스타인',
#   'object_tag': 'LC',
#   'object_pos': [39, 45],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5384590029716492},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '특히 국제 분쟁 조정을 위해 북한의 김일성, 아이티의 세드라스 장군, 팔레인스타인의 하마스, 보스니아의 세르비아계 정권 같이 미국 정부에 대해 협상을 거부하면서 사태의 위기를 초래한 인물 및 단체를 직접 만나 분쟁의 원인을 근본적으로 해결하기 위해 힘썼다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [73, 75],
#   'object': '보스니아',
#   'object_tag': 'LC',
#   'object_pos': [52, 56],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7817490100860596},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '이 과정에서 미국 행정부와 갈등을 보이기도 했지만, 전직 대통령의 권한과 재야 유명 인사들의 활약으로 해결해 나갔다.',
#   'subject': '행정부',
#   'subject_tag': 'OG',
#   'subject_pos': [10, 13],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [7, 9],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7035847902297974},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1978년에 채결된 캠프데이비드 협정의 이행이 지지부진 하자 중동 분쟁 분제를 해결하기 위해 1993년 퇴임 후 직접 이스라엘과 팔레인스타인의 오슬로 협정을 이끌어 내는 데도 성공했다.',
#   'subject': '캠프데이비드',
#   'subject_tag': 'OG',
#   'subject_pos': [11, 17],
#   'object': '이스라엘',
#   'object_tag': 'LC',
#   'object_pos': [66, 70],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5675071477890015},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '또한 이 때 김영삼 대통령과 김일성 주석의 만남을 주선했다.',
#   'subject': '김영삼',
#   'subject_tag': 'PS',
#   'subject_pos': [7, 10],
#   'object': '김일성',
#   'object_tag': 'PS',
#   'object_pos': [16, 19],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5536283850669861},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '또한 이 때 김영삼 대통령과 김일성 주석의 만남을 주선했다.',
#   'subject': '김일성',
#   'subject_tag': 'PS',
#   'subject_pos': [16, 19],
#   'object': '김영삼',
#   'object_tag': 'PS',
#   'object_pos': [7, 10],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6719628572463989},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '하지만 그로부터 수주일 후 김일성이 갑자기 사망하여 김일성과 김영삼의 정상회담은 이루어지지 못했다.',
#   'subject': '김일성',
#   'subject_tag': 'PS',
#   'subject_pos': [15, 18],
#   'object': '김일성',
#   'object_tag': 'PS',
#   'object_pos': [29, 32],
#   'relation': 'child',
#   'description': '항목 주제의 자녀',
#   'confidence': 0.7540475130081177},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '하지만 그로부터 수주일 후 김일성이 갑자기 사망하여 김일성과 김영삼의 정상회담은 이루어지지 못했다.',
#   'subject': '김일성',
#   'subject_tag': 'PS',
#   'subject_pos': [15, 18],
#   'object': '김영삼',
#   'object_tag': 'PS',
#   'object_pos': [34, 37],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8638138175010681},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '하지만 그로부터 수주일 후 김일성이 갑자기 사망하여 김일성과 김영삼의 정상회담은 이루어지지 못했다.',
#   'subject': '김일성',
#   'subject_tag': 'PS',
#   'subject_pos': [29, 32],
#   'object': '김영삼',
#   'object_tag': 'PS',
#   'object_pos': [34, 37],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.9247115850448608},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '하지만 그로부터 수주일 후 김일성이 갑자기 사망하여 김일성과 김영삼의 정상회담은 이루어지지 못했다.',
#   'subject': '김영삼',
#   'subject_tag': 'PS',
#   'subject_pos': [34, 37],
#   'object': '김일성',
#   'object_tag': 'PS',
#   'object_pos': [15, 18],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7685995697975159},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '하지만 그로부터 수주일 후 김일성이 갑자기 사망하여 김일성과 김영삼의 정상회담은 이루어지지 못했다.',
#   'subject': '김영삼',
#   'subject_tag': 'PS',
#   'subject_pos': [34, 37],
#   'object': '김일성',
#   'object_tag': 'PS',
#   'object_pos': [29, 32],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8993804454803467},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '미국의 관타나모 수용소 문제, 세계의 인권문제에서도 관심이 깊어 유엔에 유엔인권고등판무관의 제도를 시행하도록 노력하여 독재자들의 인권 유린에 대해 제약을 하고, 국제형사재판소를 만드는 데 기여하여 독재자들 같은 인권유린범죄자를 재판소로 회부하여 국제적인 처벌을 받게 하는 등 인권 신장에 크나 큰 기여를 했다.',
#   'subject': '관타나모',
#   'subject_tag': 'PS',
#   'subject_pos': [4, 8],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [0, 2],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6162143349647522},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [98, 100],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [20, 22],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6335384845733643},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [98, 100],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [66, 68],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6315866112709045},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subject': '카터',
#   'subject_tag': 'PS',
#   'subject_pos': [98, 100],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [143, 145],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5780221819877625},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '조선 시대에 훈민정음을 창제한 세종 대왕은 집현전 학자들에게 수학 연구를 명하는 등, 조선의 수학 수준을 향상시키기 위해서 많은 노력을 기울였다.',
#   'subject': '세종 대왕',
#   'subject_tag': 'PS',
#   'subject_pos': [17, 22],
#   'object': '훈민정음',
#   'object_tag': 'PS',
#   'object_pos': [7, 11],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.8399927020072937},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '조선 시대에 훈민정음을 창제한 세종 대왕은 집현전 학자들에게 수학 연구를 명하는 등, 조선의 수학 수준을 향상시키기 위해서 많은 노력을 기울였다.',
#   'subject': '세종 대왕',
#   'subject_tag': 'PS',
#   'subject_pos': [17, 22],
#   'object': '조선',
#   'object_tag': 'LC',
#   'object_pos': [48, 50],
#   'relation': 'birthPlace',
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6366021037101746},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subject': '칸토어',
#   'subject_tag': 'PS',
#   'subject_pos': [46, 49],
#   'object': '브라우어',
#   'object_tag': 'PS',
#   'object_pos': [56, 60],
#   'relation': 'influenced',
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.7521124482154846},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subject': '브라우어',
#   'subject_tag': 'PS',
#   'subject_pos': [56, 60],
#   'object': '칸토어',
#   'object_tag': 'PS',
#   'object_pos': [46, 49],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.7775774598121643},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subject': '브라우어',
#   'subject_tag': 'PS',
#   'subject_pos': [56, 60],
#   'object': '힐베르트',
#   'object_tag': 'PS',
#   'object_pos': [61, 65],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5556203126907349},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subject': '힐베르트',
#   'subject_tag': 'PS',
#   'subject_pos': [61, 65],
#   'object': '칸토어',
#   'object_tag': 'PS',
#   'object_pos': [46, 49],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5552498698234558},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subject': '힐베르트',
#   'subject_tag': 'PS',
#   'subject_pos': [61, 65],
#   'object': '브라우어',
#   'object_tag': 'PS',
#   'object_pos': [56, 60],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.554563581943512},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subject': '베오울프',
#   'subject_tag': 'PS',
#   'subject_pos': [19, 23],
#   'object': '일리아드',
#   'object_tag': 'PS',
#   'object_pos': [25, 29],
#   'relation': 'influenced',
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.7787958383560181},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subject': '일리아드',
#   'subject_tag': 'PS',
#   'subject_pos': [25, 29],
#   'object': '베오울프',
#   'object_tag': 'PS',
#   'object_pos': [19, 23],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.8371882438659668},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subject': '일리아드',
#   'subject_tag': 'PS',
#   'subject_pos': [25, 29],
#   'object': '미국',
#   'object_tag': 'LC',
#   'object_pos': [35, 37],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5977513790130615},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '예를 들어, 찰스 디킨즈의 작품들은 대부분의 사람들에게 "문학적인 것"으로 받아들여지지만, 제프리 아처의 작품들은 영문학이라는 일반적인 범주 아래 두기에는 다소 가치가 떨어지는 것으로 생각된다.',
#   'subject': '찰스 디킨즈',
#   'subject_tag': 'PS',
#   'subject_pos': [7, 13],
#   'object': '제프리 아처',
#   'object_tag': 'PS',
#   'object_pos': [51, 57],
#   'relation': 'influenced',
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.6135414242744446},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '예를 들어, 찰스 디킨즈의 작품들은 대부분의 사람들에게 "문학적인 것"으로 받아들여지지만, 제프리 아처의 작품들은 영문학이라는 일반적인 범주 아래 두기에는 다소 가치가 떨어지는 것으로 생각된다.',
#   'subject': '제프리 아처',
#   'subject_tag': 'PS',
#   'subject_pos': [51, 57],
#   'object': '찰스 디킨즈',
#   'object_tag': 'PS',
#   'object_pos': [7, 13],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5612370371818542},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subject': '보일',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 2],
#   'object': '보일',
#   'object_tag': 'PS',
#   'object_pos': [33, 35],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5140669345855713},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subject': '보일',
#   'subject_tag': 'PS',
#   'subject_pos': [17, 19],
#   'object': '보일',
#   'object_tag': 'PS',
#   'object_pos': [33, 35],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7910877466201782},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subject': '데모크리토스',
#   'subject_tag': 'PS',
#   'subject_pos': [30, 36],
#   'object': '그리스',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'birthPlace',
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6026449799537659},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subject': '존 돌턴',
#   'subject_tag': 'PS',
#   'subject_pos': [61, 65],
#   'object': '그리스',
#   'object_tag': 'LC',
#   'object_pos': [25, 28],
#   'relation': 'birthPlace',
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6312108635902405},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '영어의 isotope는 그리스어인 isos(같은)와 topos(장소)의 합성어인데, 질량은 서로 달라도 원소의 주기율표에서 같은 장소에 배열되는 데서 1901년 영국의 화학자 F.소디가 isotope라는 명칭을 붙였다.',
#   'subject': 'F',
#   'subject_tag': 'PS',
#   'subject_pos': [98, 99],
#   'object': '영국',
#   'object_tag': 'LC',
#   'object_pos': [90, 92],
#   'relation': 'nationality',
#   'description': '항목 주제의 국적',
#   'confidence': 0.5503098368644714},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1830년에서 1859년에 이르는 동안, 러시아 군은 오스만 투르크 제국과의 접경지역 안보를 이유로 체첸에 진주했다.',
#   'subject': '오스만 투르크 제국',
#   'subject_tag': 'OG',
#   'subject_pos': [30, 40],
#   'object': '러시아',
#   'object_tag': 'LC',
#   'object_pos': [23, 26],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.501361608505249},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [18, 20],
#   'object': '소비에트',
#   'object_tag': 'LC',
#   'object_pos': [13, 17],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6916264295578003},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subject': '정부',
#   'subject_tag': 'OG',
#   'subject_pos': [18, 20],
#   'object': '체첸',
#   'object_tag': 'LC',
#   'object_pos': [22, 24],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7273741960525513},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subject': '나치군',
#   'subject_tag': 'OG',
#   'subject_pos': [26, 29],
#   'object': '소비에트',
#   'object_tag': 'LC',
#   'object_pos': [13, 17],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7964996695518494},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subject': '나치군',
#   'subject_tag': 'OG',
#   'subject_pos': [26, 29],
#   'object': '체첸',
#   'object_tag': 'LC',
#   'object_pos': [22, 24],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.812677800655365},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '스탈린은 체첸 국민 전체에게 카자흐스탄으로의 강제이주를 명령했다.',
#   'subject': '스탈린',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '카자흐스탄',
#   'object_tag': 'LC',
#   'object_pos': [16, 21],
#   'relation': 'deathPlace',
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6810364723205566},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '각각의 방정식을 제임스 클러크 맥스웰이 종합한 이후 맥스웰 방정식으로 불리게 되었다.',
#   'subject': '제임스 클러크 맥스웰',
#   'subject_tag': 'PS',
#   'subject_pos': [9, 20],
#   'object': '맥스웰',
#   'object_tag': 'PS',
#   'object_pos': [29, 32],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9273855686187744},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subject': '맥스웰',
#   'subject_tag': 'PS',
#   'subject_pos': [7, 10],
#   'object': '방정식',
#   'object_tag': 'PS',
#   'object_pos': [11, 14],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9575108289718628},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subject': '로런츠',
#   'subject_tag': 'PS',
#   'subject_pos': [16, 19],
#   'object': '방정식',
#   'object_tag': 'PS',
#   'object_pos': [11, 14],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9456226229667664},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subject': '로런츠',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '맥스웰',
#   'object_tag': 'PS',
#   'object_pos': [7, 10],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7835665941238403},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subject': '맥스웰',
#   'subject_tag': 'PS',
#   'subject_pos': [7, 10],
#   'object': '로런츠',
#   'object_tag': 'PS',
#   'object_pos': [0, 3],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7909579277038574},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '샤를 드 쿨롱은 금속공과 비틀림 저울을 이용하여 두 점전하 사이에 작용하는 힘을 측정하고, 두 전하 사이에서 작용하는 힘은 두전하 크기의 곱에 비례하고 거리의 제곱에 반비례한다는 쿨롱 법칙을 발견하였다.',
#   'subject': '샤를 드 쿨롱',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 7],
#   'object': '쿨롱',
#   'object_tag': 'PS',
#   'object_pos': [100, 102],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9057896733283997},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subject': '맥스웰',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '앙드레마리 앙페르',
#   'object_tag': 'PS',
#   'object_pos': [28, 37],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.7101263999938965},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subject': '마이클 패러데이',
#   'subject_tag': 'PS',
#   'subject_pos': [5, 13],
#   'object': '앙드레마리 앙페르',
#   'object_tag': 'PS',
#   'object_pos': [28, 37],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6138680577278137},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subject': '앙드레마리 앙페르',
#   'subject_tag': 'PS',
#   'subject_pos': [28, 37],
#   'object': '맥스웰',
#   'object_tag': 'PS',
#   'object_pos': [0, 3],
#   'relation': 'influenced',
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.5608963966369629},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subject': '윌러드 기브스',
#   'subject_tag': 'PS',
#   'subject_pos': [5, 12],
#   'object': '하인리히 루돌프 헤르츠',
#   'object_tag': 'PS',
#   'object_pos': [14, 26],
#   'relation': 'influenced',
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.6766865849494934},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subject': '하인리히 루돌프 헤르츠',
#   'subject_tag': 'PS',
#   'subject_pos': [14, 26],
#   'object': '윌러드 기브스',
#   'object_tag': 'PS',
#   'object_pos': [5, 12],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6799689531326294},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '알베르트 아인슈타인은 맥스웰이 장 개념을 도입한 것에 대해 다음과 같이 평가하였다.',
#   'subject': '알베르트 아인슈타인',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 10],
#   'object': '맥스웰',
#   'object_tag': 'PS',
#   'object_pos': [12, 15],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5181042551994324},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '맥스웰은 와동의 밀도를 측정하기 위한 값으로 투자율 µ 을 정의하였다.',
#   'subject': '맥스웰',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '와동',
#   'object_tag': 'LC',
#   'object_pos': [5, 7],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9516178965568542},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '따라서 초월수의 집합은 비가산 집합이 된다.',
#   'subject': '비',
#   'subject_tag': 'PS',
#   'subject_pos': [13, 14],
#   'object': '초월수',
#   'object_tag': 'PS',
#   'object_pos': [4, 7],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5636946558952332},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '초월수의 존재는 레온하르트 오일러가 예상하였으나, 최초의 초월수는 1844년에 조제프 리우빌이 발견하였다.',
#   'subject': '조제프 리우빌',
#   'subject_tag': 'PS',
#   'subject_pos': [44, 51],
#   'object': '레온하르트 오일러',
#   'object_tag': 'PS',
#   'object_pos': [9, 18],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5919625163078308},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subject': '초월수',
#   'subject_tag': 'PS',
#   'subject_pos': [3, 6],
#   'object': '리우빌 상수',
#   'object_tag': 'PS',
#   'object_pos': [24, 30],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.901602029800415},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subject': '리우빌 상수',
#   'subject_tag': 'PS',
#   'subject_pos': [24, 30],
#   'object': '초월수',
#   'object_tag': 'PS',
#   'object_pos': [3, 6],
#   'relation': 'knownFor',
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9002698063850403},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '1900년에 다비트 힐베르트는 힐베르트의 23 문제 가운데 7번째 문제로 초월수에 대하여 다음과 같은 문제를 제시하였다.',
#   'subject': '다비트 힐베르트',
#   'subject_tag': 'PS',
#   'subject_pos': [7, 15],
#   'object': '힐베르트',
#   'object_tag': 'PS',
#   'object_pos': [17, 21],
#   'relation': 'influencedBy',
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.627402126789093},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [37, 40],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [84, 87],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7903807163238525},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [84, 87],
#   'object': '이회창',
#   'object_tag': 'PS',
#   'object_pos': [37, 40],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5989896655082703},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [8, 11],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [28, 31],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6149386167526245},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [8, 11],
#   'object': '노사모',
#   'object_tag': 'PS',
#   'object_pos': [98, 101],
#   'relation': 'spouse',
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5337232351303101},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [8, 11],
#   'object': '정몽준',
#   'object_tag': 'PS',
#   'object_pos': [126, 129],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5488308668136597},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [8, 11],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [149, 152],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6421024203300476},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [28, 31],
#   'object': '노사모',
#   'object_tag': 'PS',
#   'object_pos': [98, 101],
#   'relation': 'spouse',
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5574522614479065},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subject': '노무현',
# ...
#   'subject_pos': [19, 22],
#   'object': '이회창',
#   'object_tag': 'PS',
#   'object_pos': [11, 14],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5797938704490662},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subject': '정몽준',
#   'subject_tag': 'PS',
#   'subject_pos': [23, 26],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [19, 22],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6543811559677124},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '민주당 김원기 고문은 노무현의 결단은 "이기고 지는 것을 초월한 것"이라고 말했다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [12, 15],
#   'object': '김원기',
#   'object_tag': 'PS',
#   'object_pos': [4, 7],
#   'relation': 'vicePresident',
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5511898994445801},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [19, 22],
#   'object': '이인제',
#   'object_tag': 'PS',
#   'object_pos': [39, 42],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6118833422660828},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subject': '이인제',
#   'subject_tag': 'PS',
#   'subject_pos': [39, 42],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [19, 22],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.744867742061615},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subject': '이인제',
#   'subject_tag': 'PS',
#   'subject_pos': [39, 42],
#   'object': '이회창',
#   'object_tag': 'PS',
#   'object_pos': [63, 66],
#   'relation': 'vicePresident',
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.6895789504051208},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subject': '국민통합21',
#   'subject_tag': 'OG',
#   'subject_pos': [57, 63],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [29, 31],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.5473567843437195},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subject': '국민통합21',
#   'subject_tag': 'OG',
#   'subject_pos': [57, 63],
#   'object': '북한',
#   'object_tag': 'LC',
#   'object_pos': [89, 91],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.7592833638191223},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '정몽준',
#   'object_tag': 'PS',
#   'object_pos': [19, 22],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5100516080856323},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subject': '정몽준',
#   'subject_tag': 'PS',
#   'subject_pos': [19, 22],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [0, 3],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.580996036529541},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '정몽준',
#   'object_tag': 'PS',
#   'object_pos': [44, 47],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5452288389205933},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subject': '정몽준',
#   'subject_tag': 'PS',
#   'subject_pos': [44, 47],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [0, 3],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6628365516662598},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subject': '정몽준',
#   'subject_tag': 'PS',
#   'subject_pos': [4, 7],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [45, 48],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8826789259910583},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subject': '진영이',
#   'subject_tag': 'PS',
#   'subject_pos': [26, 29],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [45, 48],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6058288812637329},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [45, 48],
#   'object': '정몽준',
#   'object_tag': 'PS',
#   'object_pos': [4, 7],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7112634181976318},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 3],
#   'object': '이회창',
#   'object_tag': 'PS',
#   'object_pos': [45, 48],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5892874598503113},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subject': '이회창',
#   'subject_tag': 'PS',
#   'subject_pos': [45, 48],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [0, 3],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7581726312637329},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '참여정부를 표방하며 이듬해인 2003년 2월 25일 대한민국 제16대 대통령으로 취임하였다.',
#   'subject': '참여정부',
#   'subject_tag': 'PS',
#   'subject_pos': [0, 4],
#   'object': '대한민국',
#   'object_tag': 'LC',
#   'object_pos': [29, 33],
#   'relation': 'country',
#   'description': '항목 주제의 국가',
#   'confidence': 0.6937259435653687},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [5, 8],
#   'object': '참여정부',
#   'object_tag': 'PS',
#   'object_pos': [20, 24],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5016028881072998},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subject': '노무현',
#   'subject_tag': 'PS',
#   'subject_pos': [10, 13],
#   'object': '참여정부',
#   'object_tag': 'PS',
#   'object_pos': [20, 24],
#   'relation': 'predecessor',
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6034039855003357},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subject': '참여정부',
#   'subject_tag': 'PS',
#   'subject_pos': [20, 24],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [5, 8],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.605813205242157},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subject': '참여정부',
#   'subject_tag': 'PS',
#   'subject_pos': [20, 24],
#   'object': '노무현',
#   'object_tag': 'PS',
#   'object_pos': [10, 13],
#   'relation': 'successor',
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7317409515380859},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '루마니아',
#   'subject_tag': 'LC',
#   'subject_pos': [14, 18],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5994683504104614},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '핀란드',
#   'subject_tag': 'LC',
#   'subject_pos': [20, 23],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.584924042224884},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '핀란드',
#   'subject_tag': 'LC',
#   'subject_pos': [20, 23],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5499873757362366},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '영국',
#   'subject_tag': 'LC',
#   'subject_pos': [25, 27],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6270213723182678},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '영국',
#   'subject_tag': 'LC',
#   'subject_pos': [25, 27],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5782867074012756},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '스페인',
#   'subject_tag': 'LC',
#   'subject_pos': [29, 32],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.58428955078125},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '스페인',
#   'subject_tag': 'LC',
#   'subject_pos': [29, 32],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5696247816085815},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '동남아시아',
#   'subject_tag': 'LC',
#   'subject_pos': [40, 45],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6571064591407776},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '남미',
#   'subject_tag': 'LC',
#   'subject_pos': [47, 49],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5755944848060608},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '러시아',
#   'subject_tag': 'LC',
#   'subject_pos': [51, 54],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6122260093688965},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '러시아',
#   'subject_tag': 'LC',
#   'subject_pos': [51, 54],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.591923713684082},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '프랑스',
#   'subject_tag': 'LC',
#   'subject_pos': [56, 59],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.537567138671875},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '폴란드',
#   'subject_tag': 'LC',
#   'subject_pos': [61, 64],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6314495801925659},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '폴란드',
#   'subject_tag': 'LC',
#   'subject_pos': [61, 64],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6069628000259399},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '이탈리아',
#   'subject_tag': 'LC',
#   'subject_pos': [66, 70],
#   'object': '동남아시아',
#   'object_tag': 'LC',
#   'object_pos': [40, 45],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5105699896812439},
#  {'file_name': '/data/taesunwhang/entity_relation/wikipedia/entity/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subject': '이탈리아',
#   'subject_tag': 'LC',
#   'subject_pos': [66, 70],
#   'object': '남미',
#   'object_tag': 'LC',
#   'object_pos': [47, 49],
#   'relation': 'location',
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5640079379081726},
#  ...]

# %%
if not os.path.exists("../data/modified_KBN_data"):
    os.mkdir("../data/modified_KBN_data")

# %% [markdown]
# ### 데이터 변형

# %%
modify_data(input_filepath=file_example)

# %% [markdown]
# ### 변형된 데이터 형식

# %%
with open("../data/modified_KBN_data/wikipedia_0001.json") as f:
    modified_json_data = json.load(f)
modified_json_data
# Out:
# [{'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8254553079605103},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5040757060050964},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7290757298469543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.605682373046875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '민주당', 'pos': [37, 40], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8298603892326355},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subj': {'name': '섬터 카운티', 'pos': [12, 18], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [7, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.776265561580658},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subj': {'name': '플레인스', 'pos': [19, 23], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [7, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7227185368537903},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1953년 미국 해군 대위로 예편하였고 이후 땅콩·면화 등을 가꿔 많은 돈을 벌었다.',
#   'subj': {'name': '해군', 'pos': [9, 11], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [6, 8], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.9773654937744141},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subj': {'name': '조지아', 'pos': [63, 66], 'type': 'LC'},
#   'obj': {'name': '조지아 주', 'pos': [6, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7467160820960999},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subj': {'name': '조지아', 'pos': [88, 91], 'type': 'LC'},
#   'obj': {'name': '조지아 주', 'pos': [6, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.735164999961853},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대통령이 되기 전 조지아주 상원의원을 두번 연임했으며, 1971년부터 1975년까지 조지아 지사로 근무했다.',
#   'subj': {'name': '조지아', 'pos': [47, 50], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [10, 14], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7667058110237122},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '이집트', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6622843146324158},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '이스라엘', 'pos': [9, 13], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7659438848495483},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7613891363143921},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6384792327880859},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7651193141937256},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '이집트', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.522010087966919},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '이스라엘', 'pos': [9, 13], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6861956715583801},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5805528163909912},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'obj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7331639528274536},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'obj': {'name': '이집트', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.619739294052124},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'obj': {'name': '이스라엘', 'pos': [9, 13], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7720767855644226},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 이것은 공화당과 미국의 유대인 단체의 반발을 일으켰다.',
#   'subj': {'name': '공화당', 'pos': [8, 11], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [13, 15], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7262453436851501},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 1970년대 후반 당시 대한민국 등 인권 후진국의 국민들의 인권을 지키기 위해 노력했으며, 취임 이후 계속해서 도덕정치를 내세웠다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '대한민국', 'pos': [17, 21], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6086249947547913},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지미 카터는 대한민국과의 관계에서도 중요한 영향을 미쳤던 대통령 중 하나다.',
#   'subj': {'name': '지미 카터', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '대한민국', 'pos': [7, 11], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5950901508331299},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '인권 문제와 주한미군 철수 문제로 한때 한미 관계가 불편하기도 했다.',
#   'subj': {'name': '주한미군', 'pos': [7, 11], 'type': 'OG'},
#   'obj': {'name': '한', 'pos': [22, 23], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8219428062438965},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '인권 문제와 주한미군 철수 문제로 한때 한미 관계가 불편하기도 했다.',
#   'subj': {'name': '주한미군', 'pos': [7, 11], 'type': 'OG'},
#   'obj': {'name': '미', 'pos': [23, 24], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8799412250518799},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subj': {'name': '한미연합사', 'pos': [27, 32], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [15, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7299146056175232},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subj': {'name': '주한미군', 'pos': [57, 61], 'type': 'OG'},
#   'obj': {'name': '대한민국', 'pos': [6, 10], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.674068808555603},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1978년 대한민국에 대한 북한의 위협에 대비해 한미연합사를 창설하면서, 1982년까지 3단계에 걸쳐 주한미군을 철수하기로 했다.',
#   'subj': {'name': '주한미군', 'pos': [57, 61], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [15, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8647246956825256},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '10월 26일, 박정희 대통령이 김재규 중앙정보부장에 의해 살해된 것에 대해 그는 이 사건으로 큰 충격을 받았으며, 사이러스 밴스 국무장관을 조문사절로 파견했다.',
#   'subj': {'name': '박정희', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': '김재규', 'pos': [18, 21], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5391024947166443},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '12·12 군사 반란과 5.17 쿠데타에 대해 초기에는 강하게 비난했으나, 미국 정부가 신군부를 설득하는데, 한계가 있었고 결국 묵인하는 듯한 태도를 보이게 됐다.',
#   'subj': {'name': '정부', 'pos': [45, 47], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [42, 44], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8037638664245605},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [14, 16], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5240483283996582},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '코소보', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.60670006275177},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 카터 행정부 이후 미국이 북핵 위기, 코소보 전쟁, 이라크 전쟁과 같이 미국이 군사적 행동을 최후로 선택하는 전통적 사고를 버리고 군사적 행동을 선행하는 행위에 대해 깊은 유감을 표시 하며 미국의 군사적 활동에 강한 반대 입장을 보이고 있다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.
 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5612370371818542},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subj': {'name': '보일', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '보일', 'pos': [33, 35], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5140669345855713},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subj': {'name': '보일', 'pos': [17, 19], 'type': 'PS'},
#   'obj': {'name': '보일', 'pos': [33, 35], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7910877466201782},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subj': {'name': '데모크리토스', 'pos': [30, 36], 'type': 'PS'},
#   'obj': {'name': '그리스', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6026449799537659},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subj': {'name': '존 돌턴', 'pos': [61, 65], 'type': 'PS'},
#   'obj': {'name': '그리스', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6312108635902405},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '영어의 isotope는 그리스어인 isos(같은)와 topos(장소)의 합성어인데, 질량은 서로 달라도 원소의 주기율표에서 같은 장소에 배열되는 데서 1901년 영국의 화학자 F.소디가 isotope라는 명칭을 붙였다.',
#   'subj': {'name': 'F', 'pos': [98, 99], 'type': 'PS'},
#   'obj': {'name': '영국', 'pos': [90, 92], 'type': 'LC'},
#   'description': '항목 주제의 국적',
#   'confidence': 0.5503098368644714},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1830년에서 1859년에 이르는 동안, 러시아 군은 오스만 투르크 제국과의 접경지역 안보를 이유로 체첸에 진주했다.',
#   'subj': {'name': '오스만 투르크 제국', 'pos': [30, 40], 'type': 'OG'},
#   'obj': {'name': '러시아', 'pos': [23, 26], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.501361608505249},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '정부', 'pos': [18, 20], 'type': 'OG'},
#   'obj': {'name': '소비에트', 'pos': [13, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6916264295578003},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '정부', 'pos': [18, 20], 'type': 'OG'},
#   'obj': {'name': '체첸', 'pos': [22, 24], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7273741960525513},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '나치군', 'pos': [26, 29], 'type': 'OG'},
#   'obj': {'name': '소비에트', 'pos': [13, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7964996695518494},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '나치군', 'pos': [26, 29], 'type': 'OG'},
#   'obj': {'name': '체첸', 'pos': [22, 24], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.812677800655365},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '스탈린은 체첸 국민 전체에게 카자흐스탄으로의 강제이주를 명령했다.',
#   'subj': {'name': '스탈린', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '카자흐스탄', 'pos': [16, 21], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6810364723205566},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '각각의 방정식을 제임스 클러크 맥스웰이 종합한 이후 맥스웰 방정식으로 불리게 되었다.',
#   'subj': {'name': '제임스 클러크 맥스웰', 'pos': [9, 20], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [29, 32], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9273855686187744},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'obj': {'name': '방정식', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9575108289718628},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subj': {'name': '로런츠', 'pos': [16, 19], 'type': 'PS'},
#   'obj': {'name': '방정식', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9456226229667664},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subj': {'name': '로런츠', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7835665941238403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'obj': {'name': '로런츠', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7909579277038574},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '샤를 드 쿨롱은 금속공과 비틀림 저울을 이용하여 두 점전하 사이에 작용하는 힘을 측정하고, 두 전하 사이에서 작용하는 힘은 두전하 크기의 곱에 비례하고 거리의 제곱에 반비례한다는 쿨롱 법칙을 발견하였다.',
#   'subj': {'name': '샤를 드 쿨롱', 'pos': [0, 7], 'type': 'PS'},
#   'obj': {'name': '쿨롱', 'pos': [100, 102], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9057896733283997},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.7101263999938965},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '마이클 패러데이', 'pos': [5, 13], 'type': 'PS'},
#   'obj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6138680577278137},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.5608963966369629},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subj': {'name': '윌러드 기브스', 'pos': [5, 12], 'type': 'PS'},
#   'obj': {'name': '하인리히 루돌프 헤르츠', 'pos': [14, 26], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.6766865849494934},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subj': {'name': '하인리히 루돌프 헤르츠', 'pos': [14, 26], 'type': 'PS'},
#   'obj': {'name': '윌러드 기브스', 'pos': [5, 12], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6799689531326294},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '알베르트 아인슈타인은 맥스웰이 장 개념을 도입한 것에 대해 다음과 같이 평가하였다.',
#   'subj': {'name': '알베르트 아인슈타인', 'pos': [0, 10], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [12, 15], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5181042551994324},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 와동의 밀도를 측정하기 위한 값으로 투자율 µ 을 정의하였다.',
#   'subj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '와동', 'pos': [5, 7], 'type': 'LC'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9516178965568542},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '따라서 초월수의 집합은 비가산 집합이 된다.',
#   'subj': {'name': '비', 'pos': [13, 14], 'type': 'PS'},
#   'obj': {'name': '초월수', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5636946558952332},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '초월수의 존재는 레온하르트 오일러가 예상하였으나, 최초의 초월수는 1844년에 조제프 리우빌이 발견하였다.',
#   'subj': {'name': '조제프 리우빌', 'pos': [44, 51], 'type': 'PS'},
#   'obj': {'name': '레온하르트 오일러', 'pos': [9, 18], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5919625163078308},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subj': {'name': '초월수', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '리우빌 상수', 'pos': [24, 30], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.901602029800415},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subj': {'name': '리우빌 상수', 'pos': [24, 30], 'type': 'PS'},
#   'obj': {'name': '초월수', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9002698063850403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1900년에 다비트 힐베르트는 힐베르트의 23 문제 가운데 7번째 문제로 초월수에 대하여 다음과 같은 문제를 제시하였다.',
#   'subj': {'name': '다비트 힐베르트', 'pos': [7, 15], 'type': 'PS'},
#   'obj': {'name': '힐베르트', 'pos': [17, 21], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.627402126789093},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subj': {'name': '이회창', 'pos': [37, 40], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [84, 87], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7903807163238525},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subj': {'name': '노무현', 'pos': [84, 87], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [37, 40], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5989896655082703},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6149386167526245},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5337232351303101},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5488308668136597},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6421024203300476},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5574522614479065},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5329466462135315},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [75, 78], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.6729810833930969},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [75, 78], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5330564975738525},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5594007968902588},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5612156987190247},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5412212014198303},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.837002158164978},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6452248096466064},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6507483124732971},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8399055600166321},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '새천년민주당은 3월 9일부터 4월 27일까지 한국 정당 역사상 최초로 국민 참여 경선을 실시하고 과반 득표자인 노무현 전 해양수산부 장관을 대통령 후보로 선출하였다.',
#   'subj': {'name': '새천년민주당', 'pos': [0, 6], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [25, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8249130249023438},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '새천년민주당은 3월 9일부터 4월 27일까지 한국 정당 역사상 최초로 국민 참여 경선을 실시하고 과반 득표자인 노무현 전 해양수산부 장관을 대통령 후보로 선출하였다.',
#   'subj': {'name': '해양수산부', 'pos': [68, 73], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [25, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6931378245353699},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 박근혜 부총재는 2월 28일 이회창 총재의 리더십을 비판하며 한나라당을 탈당하였으며, 이후 신당을 창당하여 독자적으로 대선에 출마할 뜻을 밝혔다.',
#   'subj': {'name': '박근혜', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [20, 23], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7769392132759094},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 박근혜 부총재는 2월 28일 이회창 총재의 리더십을 비판하며 한나라당을 탈당하였으며, 이후 신당을 창당하여 독자적으로 대선에 출마할 뜻을 밝혔다.',
#   'subj': {'name': '이회창', 'pos': [20, 23], 'type': 'PS'},
#   'obj': {'name': '박근혜', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.5210031867027283},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제16대 대선은 민주당의 노무현 후보와 한나라당의 이회창 후보, 두 후보의 양자 대결 구도로 진행되어, 1971년 제7대 대선 이후 최초로 3자, 4자가 아닌 양자 구도로 치러진 대선이 되었다.',
#   'subj': {'name': '노무현', 'pos': [14, 17], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.512476921081543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제16대 대선은 민주당의 노무현 후보와 한나라당의 이회창 후보, 두 후보의 양자 대결 구도로 진행되어, 1971년 제7대 대선 이후 최초로 3자, 4자가 아닌 양자 구도로 치러진 대선이 되었다.',
#   'subj': {'name': '이회창', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [14, 17], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7836214900016785},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 제15대 대선에서 패한 후 차근차근 대권 재도전을 준비해오던 이회창 후보가 한나라당을 완전히 장악하고 있었던 것과 달리, 진보 성향 인사이면서 보수 정당 민주당의 후보가 된 노무현 후보는 끊임없이 당 내부에서 공격을 받고 있었다.',
#   'subj': {'name': '이회창', 'pos': [38, 41], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [101, 104], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8392730355262756},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 제15대 대선에서 패한 후 차근차근 대권 재도전을 준비해오던 이회창 후보가 한나라당을 완전히 장악하고 있었던 것과 달리, 진보 성향 인사이면서 보수 정당 민주당의 후보가 된 노무현 후보는 끊임없이 당 내부에서 공격을 받고 있었다.',
#   'subj': {'name': '노무현', 'pos': [101, 104], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [38, 41], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8668186664581299},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': "이같은 상황에서 이회창의 당선이 유력시되고 있었으나, 제15대 대선과 마찬가지로 아들 병역기피 의혹에 시달리며 난관에 봉착한데다 노무현 후보가 이른바 '노풍'을 일으키며 선풍적 인기를 끌어 승패를 예측할 수 없게 되었다.",
#   'subj': {'name': '이회창', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [72, 75], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7270421385765076},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6164760589599609},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [47, 50], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7273812294006348},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6392078399658203},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
# ...
#   'confidence': 0.7147538065910339},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현의 낙마를 바라는 의원들이 탈당하여 후보 단일화 추진 협의회(후단협)를 만들고 후보 단일화를 주장했는데, 이들은 노무현으로 후보 단일화가 되면 함께 할 수 없다고 발언하였고 정몽준 지지의 속내를 감추지 않았다.',
#   'subj': {'name': '정몽준', 'pos': [100, 103], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [66, 69], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7422971725463867},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '정몽준', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8403524160385132},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '김민석', 'pos': [24, 27], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6734470129013062},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5250436067581177},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이 중 협상 담판은 정몽준의 후보의 주장으로 11월 1일에 정식 제안했고, 국민 경선안은 국민 참여 50%, 당원 참여 50%의 민주당 안을 노무현 후보가 11월 3일 정식 제안했다.',
#   'subj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [79, 82], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.824262261390686},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이 중 협상 담판은 정몽준의 후보의 주장으로 11월 1일에 정식 제안했고, 국민 경선안은 국민 참여 50%, 당원 참여 50%의 민주당 안을 노무현 후보가 11월 3일 정식 제안했다.',
#   'subj': {'name': '노무현', 'pos': [79, 82], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8907572031021118},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7680083513259888},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [23, 26], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5549456477165222},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5797938704490662},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '정몽준', 'pos': [23, 26], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6543811559677124},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '민주당 김원기 고문은 노무현의 결단은 "이기고 지는 것을 초월한 것"이라고 말했다.',
#   'subj': {'name': '노무현', 'pos': [12, 15], 'type': 'PS'},
#   'obj': {'name': '김원기', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5511898994445801},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6118833422660828},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.744867742061615},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [63, 66], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.6895789504051208},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subj': {'name': '국민통합21', 'pos': [57, 63], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [29, 31], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5473567843437195},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subj': {'name': '국민통합21', 'pos': [57, 63], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [89, 91], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7592833638191223},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5100516080856323},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subj': {'name': '정몽준', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.580996036529541},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [44, 47], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5452288389205933},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subj': {'name': '정몽준', 'pos': [44, 47], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6628365516662598},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '정몽준', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8826789259910583},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '진영이', 'pos': [26, 29], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6058288812637329},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7112634181976318},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5892874598503113},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subj': {'name': '이회창', 'pos': [45, 48], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7581726312637329},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '참여정부를 표방하며 이듬해인 2003년 2월 25일 대한민국 제16대 대통령으로 취임하였다.',
#   'subj': {'name': '참여정부', 'pos': [0, 4], 'type': 'PS'},
#   'obj': {'name': '대한민국', 'pos': [29, 33], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6937259435653687},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '노무현', 'pos': [5, 8], 'type': 'PS'},
#   'obj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5016028881072998},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '노무현', 'pos': [10, 13], 'type': 'PS'},
#   'obj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6034039855003357},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [5, 8], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.605813205242157},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [10, 13], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7317409515380859},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '루마니아', 'pos': [14, 18], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5994683504104614},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '핀란드', 'pos': [20, 23], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.584924042224884},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '핀란드', 'pos': [20, 23], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5499873757362366},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '영국', 'pos': [25, 27], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6270213723182678},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '영국', 'pos': [25, 27], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5782867074012756},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '스페인', 'pos': [29, 32], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.58428955078125},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '스페인', 'pos': [29, 32], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5696247816085815},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6571064591407776},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5755944848060608},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '러시아', 'pos': [51, 54], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6122260093688965},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '러시아', 'pos': [51, 54], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.591923713684082},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '프랑스', 'pos': [56, 59], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.537567138671875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '폴란드', 'pos': [61, 64], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6314495801925659},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '폴란드', 'pos': [61, 64], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6069628000259399},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '이탈리아', 'pos': [66, 70], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5105699896812439},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '이탈리아', 'pos': [66, 70], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.
#  '../data/modified_KBN_data/wikipedia_0402.json',
#  '../data/modified_KBN_data/wikipedia_0403.json',
#  '../data/modified_KBN_data/wikipedia_0404.json',
#  '../data/modified_KBN_data/wikipedia_0405.json',
#  '../data/modified_KBN_data/wikipedia_0406.json',
#  '../data/modified_KBN_data/wikipedia_0407.json',
#  '../data/modified_KBN_data/wikipedia_0408.json',
#  '../data/modified_KBN_data/wikipedia_0409.json',
#  '../data/modified_KBN_data/wikipedia_0410.json']

# %% [markdown]
# ## 변형된 전체 json file 통합

# %%
def combine_json_data(file_list):
    """ file_list에 존재하는 전체 wikipedia_XXXX.json 파일을
        하나의 리스트에 저장하고 리스트를 return하는 함수.
    """
    data = []
    for json_file in file_list:
        with open(json_file) as f:
            json_data = json.load(f)
            for sent in json_data:
                data.append(sent)
    return data

# %%
total_data = combine_json_data(modified_file_list)

# %%
len(total_data)
# Out:
# 4476095

# %%
total_data[0]
# Out:
# {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#  'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#  'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#  'obj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#  'description': '항목 주제의 후임자',
#  'confidence': 0.8254553079605103}

# %%
total_data[:5]
# Out:
# [{'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8254553079605103},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5040757060050964},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7290757298469543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.605682373046875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '민주당', 'pos': [37, 40], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8298603892326355}]

# %% [markdown]
# ## 전체 data에 존재하는 relation 정보 인코딩

# %%
def write_rel2id(filename, data):
    """ 전체 data에 존재하는 relation을 숫자로 인코딩하여 json file로 저장하는 함수.
    """
    rel2id = dict()
    rel_idx = 0
    for item in data:
        if item["description"] not in rel2id:
            rel2id[item["description"]] = rel_idx
            rel_idx += 1

    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(rel2id, f, ensure_ascii=False, indent=4)

# %%
write_rel2id("../data/rel2id.json", total_data)

# %% [markdown]
# ### rel2id.json

# %%
with open("../data/rel2id.json", 'r') as f:
    rel2id = json.load(f)
rel2id
# Out:
# {'항목 주제의 후임자': 0,
#  '항목 주제의 국가': 1,
#  '항목 주제의 전임자': 2,
#  '항목 주제가 있거나 연결되어있는 지역': 3,
#  '항목 주제의 부통령 혹은 총리': 4,
#  '항목 주제의 자녀': 5,
#  '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등': 6,
#  '항목 주제가 태어난 장소': 7,
#  '항목 주제가 영향을 준 것': 8,
#  '항목 주제에 영향을 준 것': 9,
#  '항목 주제의 국적': 10,
#  '항목 주제가 죽은 장소': 11,
#  '항목 주제인 인물의 배우자 (동거인의 개념은 아님)': 12,
#  '항목 주제의 부모': 13,
#  '항목 주제의 친척': 14,
#  '항목 주제인 지방 정부나 중앙 정부가 위치한 도시/자치도시': 15,
#  '항목 주제가 위치한 행정 구역': 16,
#  '항목 주제가 위치한 지역': 17,
#  '항목 주제인 인물이 교육받은 곳': 18,
#  '항목 주제인 장소에서의 가장 큰 도시': 19,
#  '항목 주제의 지도자': 20,
#  '항목 주제인 단체의 설립자': 21,
#  '항목 주제의 소유 조직': 22,
#  '항목 주제인 팀이 출전한 리그': 23,
#  '항목 주제의 지휘관': 24,
#  '항목 주제인 조직 기관의 중요 인물': 25,
#  '항목 주제을(를) 소유하고 있는 사람/단체': 26,
#  '항목 주제의 자회사': 27,
#  '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교': 28,
#  '항목 주제인 창작물의 제작자': 29,
#  '항목 주제의 상대나 반대자': 30,
#  '항목 주제인 경로가 시작되는 곳': 31,
#  '항목 주제의 시작이 되는 산': 32,
#  '항목 주제인 경로가 끝나는 곳': 33,
#  '항목 주제의 세입자나 임차인': 34,
#  '항목 주제인 인물의 안식처, 무덤': 35,
#  '항목 주제인 항공사의 허브공항': 36,
#  '항목 주제인 스포츠 팀의 현재 소속 선수': 37,
#  '항목 주제가 현재나 과거에 활동했던 스포츠 팀': 38,
#  '항목 주제인 인종 집단의 구성원들이 살고있는 곳': 39,
#  '항목 주제을(를) 위해 마련된 거주 시설, 임기 동안 거주한 장소': 40,
#  '항목 주제인 운동선수의 소속 팀': 41,
#  '항목 주제의 이전 멤버': 42,
#  '항목 주제인 운동선수의 국가대표 팀': 43,
#  '항목 주제인 음악 레코딩과 뮤직비디오의 마케팅을 위한 브랜드나 상표': 44,
#  '항목 주제인 조직이나 단체의 본거지가 있거나 세워져 있는 구체적인 위치': 45,
#  '항목 주제인 군사 부대의 주둔지': 46}

# %% [markdown]
# ## train.txt, dev.txt, test.txt 파일 쓰기

# %%
len(total_data)
# Out:
# 4476095

# %%
total_data[0]
# Out:
# {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#  'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#  'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#  'obj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#  'description': '항목 주제의 후임자',
#  'confidence': 0.8254553079605103}

# %%
train_data = total_data[:int(0.6 * len(total_data))]
dev_data = total_data[int(0.6 * len(total_data)):int(0.8 * len(total_data))]
test_data = total_data[int(0.8 * len(total_data)):]

# %%
len(train_data)
# Out:
# 2685657

# %%
len(dev_data)
# Out:
# 895219

# %%
len(test_data)
# Out:
# 895219

# %%
len(train_data) + len(dev_data) + len(test_data)
# Out:
# 4476095

# %%
train_data
# Out:
# [{'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8254553079605103},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5040757060050964},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '제임스 얼', 'pos': [0, 5], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7290757298469543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '카터 주니어', 'pos': [10, 16], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.605682373046875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제임스 얼 "지미"카터 주니어(, 1924년 10월 1일 ~ )는 민주당 출신 미국 39번째 대통령 (1977년 ~ 1981년)이다.',
#   'subj': {'name': '민주당', 'pos': [37, 40], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [44, 46], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8298603892326355},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subj': {'name': '섬터 카운티', 'pos': [12, 18], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [7, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.776265561580658},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지미 카터는 조지아주 섬터 카운티 플레인스 마을에서 태어났다.',
#   'subj': {'name': '플레인스', 'pos': [19, 23], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [7, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7227185368537903},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1953년 미국 해군 대위로 예편하였고 이후 땅콩·면화 등을 가꿔 많은 돈을 벌었다.',
#   'subj': {'name': '해군', 'pos': [9, 11], 'type': 'OG'},
#   'obj': {'name': '미국', 'pos': [6, 8], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.9773654937744141},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subj': {'name': '조지아', 'pos': [63, 66], 'type': 'LC'},
#   'obj': {'name': '조지아 주', 'pos': [6, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7467160820960999},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1962년 조지아 주 상원 의원 선거에서 낙선하나 그 선거가 부정선거 였음을 입증하게 되어 당선되고, 1966년 조지아 주 지사 선거에 낙선하지만 1970년 조지아 주 지사를 역임했다.',
#   'subj': {'name': '조지아', 'pos': [88, 91], 'type': 'LC'},
#   'obj': {'name': '조지아 주', 'pos': [6, 11], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.735164999961853},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대통령이 되기 전 조지아주 상원의원을 두번 연임했으며, 1971년부터 1975년까지 조지아 지사로 근무했다.',
#   'subj': {'name': '조지아', 'pos': [47, 50], 'type': 'LC'},
#   'obj': {'name': '조지아주', 'pos': [10, 14], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.7667058110237122},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '이집트', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6622843146324158},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '이스라엘', 'pos': [9, 13], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7659438848495483},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7613891363143921},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '메나헴 베긴', 'pos': [44, 50], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6384792327880859},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '카터', 'pos': [0, 2], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7651193141937256},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '이집트', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.522010087966919},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name': '안와르 사다트', 'pos': [31, 38], 'type': 'PS'},
#   'obj': {'name': '이스라엘', 'pos': [9, 13], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6861956715583801},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '카터는 이집트와 이스라엘을 조정하여, 캠프 데이비드에서 안와르 사다트 대통령과 메나헴 베긴 수상과 함께 중동 평화를 위한 캠프데이비드 협정을 체결했다.',
#   'subj': {'name':

#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subj': {'name': '카터', 'pos': [98, 100], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [20, 22], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6335384845733643},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subj': {'name': '카터', 'pos': [98, 100], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [66, 68], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6315866112709045},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '경제문제를 해결하지 못하고 주 이란 미국 대사관 인질 사건에 발목이 잡혀 실패한 대통령으로 평가를 받지만 이란 사태는 미국 내 이란 재산을 풀어주겠다는 조건을 내세워서 사실상 카터가 해결한 것이었고, 사랑의 집짓기 운동 등으로 퇴임 후에 훨씬 더 존경받는 미국 대통령 중에 특이한 인물로 남았다.',
#   'subj': {'name': '카터', 'pos': [98, 100], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [143, 145], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5780221819877625},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조선 시대에 훈민정음을 창제한 세종 대왕은 집현전 학자들에게 수학 연구를 명하는 등, 조선의 수학 수준을 향상시키기 위해서 많은 노력을 기울였다.',
#   'subj': {'name': '세종 대왕', 'pos': [17, 22], 'type': 'PS'},
#   'obj': {'name': '훈민정음', 'pos': [7, 11], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.8399927020072937},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조선 시대에 훈민정음을 창제한 세종 대왕은 집현전 학자들에게 수학 연구를 명하는 등, 조선의 수학 수준을 향상시키기 위해서 많은 노력을 기울였다.',
#   'subj': {'name': '세종 대왕', 'pos': [17, 22], 'type': 'PS'},
#   'obj': {'name': '조선', 'pos': [48, 50], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6366021037101746},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subj': {'name': '칸토어', 'pos': [46, 49], 'type': 'PS'},
#   'obj': {'name': '브라우어', 'pos': [56, 60], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.7521124482154846},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subj': {'name': '브라우어', 'pos': [56, 60], 'type': 'PS'},
#   'obj': {'name': '칸토어', 'pos': [46, 49], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.7775774598121643},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subj': {'name': '브라우어', 'pos': [56, 60], 'type': 'PS'},
#   'obj': {'name': '힐베르트', 'pos': [61, 65], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5556203126907349},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subj': {'name': '힐베르트', 'pos': [61, 65], 'type': 'PS'},
#   'obj': {'name': '칸토어', 'pos': [46, 49], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5552498698234558},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '수학의 기초에 대한 위기는 그 당시 수많은 논쟁에 의해 촉발되었으며, 그 논쟁에는 칸토어의 집합론과 브라우어-힐베르트 논쟁이 포함되었다.',
#   'subj': {'name': '힐베르트', 'pos': [61, 65], 'type': 'PS'},
#   'obj': {'name': '브라우어', 'pos': [56, 60], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.554563581943512},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subj': {'name': '베오울프', 'pos': [19, 23], 'type': 'PS'},
#   'obj': {'name': '일리아드', 'pos': [25, 29], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.7787958383560181},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subj': {'name': '일리아드', 'pos': [25, 29], 'type': 'PS'},
#   'obj': {'name': '베오울프', 'pos': [19, 23], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.8371882438659668},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '예를 들어 고대 그리스어, 성서, 베오울프, 일리아드, 그리고 미국 헌법 등이 그러한 분류의 범주에 들어간다.',
#   'subj': {'name': '일리아드', 'pos': [25, 29], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [35, 37], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5977513790130615},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '예를 들어, 찰스 디킨즈의 작품들은 대부분의 사람들에게 "문학적인 것"으로 받아들여지지만, 제프리 아처의 작품들은 영문학이라는 일반적인 범주 아래 두기에는 다소 가치가 떨어지는 것으로 생각된다.',
#   'subj': {'name': '찰스 디킨즈', 'pos': [7, 13], 'type': 'PS'},
#   'obj': {'name': '제프리 아처', 'pos': [51, 57], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.6135414242744446},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '예를 들어, 찰스 디킨즈의 작품들은 대부분의 사람들에게 "문학적인 것"으로 받아들여지지만, 제프리 아처의 작품들은 영문학이라는 일반적인 범주 아래 두기에는 다소 가치가 떨어지는 것으로 생각된다.',
#   'subj': {'name': '제프리 아처', 'pos': [51, 57], 'type': 'PS'},
#   'obj': {'name': '찰스 디킨즈', 'pos': [7, 13], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5612370371818542},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subj': {'name': '보일', 'pos': [0, 2], 'type': 'PS'},
#   'obj': {'name': '보일', 'pos': [33, 35], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5140669345855713},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '보일이 원래 발견자가 아님에도 보일은 1662 년에 제시한 보일의 법칙으로 가장 잘 알려져있다.',
#   'subj': {'name': '보일', 'pos': [17, 19], 'type': 'PS'},
#   'obj': {'name': '보일', 'pos': [33, 35], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7910877466201782},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subj': {'name': '데모크리토스', 'pos': [30, 36], 'type': 'PS'},
#   'obj': {'name': '그리스', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6026449799537659},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '원자란 물질을 구성하는 기본적인 입자로 고대 그리스의 데모크리토스에서부터 그 존재가 주장되었는데, 1803년 존 돌턴에 의해서 원자론으로 정리되었다.',
#   'subj': {'name': '존 돌턴', 'pos': [61, 65], 'type': 'PS'},
#   'obj': {'name': '그리스', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6312108635902405},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '영어의 isotope는 그리스어인 isos(같은)와 topos(장소)의 합성어인데, 질량은 서로 달라도 원소의 주기율표에서 같은 장소에 배열되는 데서 1901년 영국의 화학자 F.소디가 isotope라는 명칭을 붙였다.',
#   'subj': {'name': 'F', 'pos': [98, 99], 'type': 'PS'},
#   'obj': {'name': '영국', 'pos': [90, 92], 'type': 'LC'},
#   'description': '항목 주제의 국적',
#   'confidence': 0.5503098368644714},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1830년에서 1859년에 이르는 동안, 러시아 군은 오스만 투르크 제국과의 접경지역 안보를 이유로 체첸에 진주했다.',
#   'subj': {'name': '오스만 투르크 제국', 'pos': [30, 40], 'type': 'OG'},
#   'obj': {'name': '러시아', 'pos': [23, 26], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.501361608505249},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '정부', 'pos': [18, 20], 'type': 'OG'},
#   'obj': {'name': '소비에트', 'pos': [13, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6916264295578003},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '정부', 'pos': [18, 20], 'type': 'OG'},
#   'obj': {'name': '체첸', 'pos': [22, 24], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7273741960525513},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '나치군', 'pos': [26, 29], 'type': 'OG'},
#   'obj': {'name': '소비에트', 'pos': [13, 17], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7964996695518494},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제2차 세계 대전 동안 소비에트 정부는 체첸이 나치군과 협력했다고 맹비난하였다.',
#   'subj': {'name': '나치군', 'pos': [26, 29], 'type': 'OG'},
#   'obj': {'name': '체첸', 'pos': [22, 24], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.812677800655365},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '스탈린은 체첸 국민 전체에게 카자흐스탄으로의 강제이주를 명령했다.',
#   'subj': {'name': '스탈린', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '카자흐스탄', 'pos': [16, 21], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6810364723205566},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '각각의 방정식을 제임스 클러크 맥스웰이 종합한 이후 맥스웰 방정식으로 불리게 되었다.',
#   'subj': {'name': '제임스 클러크 맥스웰', 'pos': [9, 20], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [29, 32], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9273855686187744},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'obj': {'name': '방정식', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9575108289718628},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '전자기역학은 맥스웰 방정식과 로런츠 힘 법칙으로 요약된다.',
#   'subj': {'name': '로런츠', 'pos': [16, 19], 'type': 'PS'},
#   'obj': {'name': '방정식', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9456226229667664},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subj': {'name': '로런츠', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7835665941238403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '로런츠 힘은 맥스웰 방정식으로부터 유도될 수 있다.',
#   'subj': {'name': '맥스웰', 'pos': [7, 10], 'type': 'PS'},
#   'obj': {'name': '로런츠', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.7909579277038574},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '샤를 드 쿨롱은 금속공과 비틀림 저울을 이용하여 두 점전하 사이에 작용하는 힘을 측정하고, 두 전하 사이에서 작용하는 힘은 두전하 크기의 곱에 비례하고 거리의 제곱에 반비례한다는 쿨롱 법칙을 발견하였다.',
#   'subj': {'name': '샤를 드 쿨롱', 'pos': [0, 7], 'type': 'PS'},
#   'obj': {'name': '쿨롱', 'pos': [100, 102], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9057896733283997},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.7101263999938965},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '마이클 패러데이', 'pos': [5, 13], 'type': 'PS'},
#   'obj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6138680577278137},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 마이클 패러데이의 "역선"(力線) 개념과 앙드레마리 앙페르의 회로 이론을 근간으로 방정식을 정리하였다.',
#   'subj': {'name': '앙드레마리 앙페르', 'pos': [28, 37], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.5608963966369629},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subj': {'name': '윌러드 기브스', 'pos': [5, 12], 'type': 'PS'},
#   'obj': {'name': '하인리히 루돌프 헤르츠', 'pos': [14, 26], 'type': 'PS'},
#   'description': '항목 주제가 영향을 준 것',
#   'confidence': 0.6766865849494934},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '조사이어 윌러드 기브스와 하인리히 루돌프 헤르츠 역시 헤비사이드와 동일한 작업을 한 바 있다.',
#   'subj': {'name': '하인리히 루돌프 헤르츠', 'pos': [14, 26], 'type': 'PS'},
#   'obj': {'name': '윌러드 기브스', 'pos': [5, 12], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.6799689531326294},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '알베르트 아인슈타인은 맥스웰이 장 개념을 도입한 것에 대해 다음과 같이 평가하였다.',
#   'subj': {'name': '알베르트 아인슈타인', 'pos': [0, 10], 'type': 'PS'},
#   'obj': {'name': '맥스웰', 'pos': [12, 15], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5181042551994324},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '맥스웰은 와동의 밀도를 측정하기 위한 값으로 투자율 µ 을 정의하였다.',
#   'subj': {'name': '맥스웰', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '와동', 'pos': [5, 7], 'type': 'LC'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9516178965568542},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '따라서 초월수의 집합은 비가산 집합이 된다.',
#   'subj': {'name': '비', 'pos': [13, 14], 'type': 'PS'},
#   'obj': {'name': '초월수', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.5636946558952332},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '초월수의 존재는 레온하르트 오일러가 예상하였으나, 최초의 초월수는 1844년에 조제프 리우빌이 발견하였다.',
#   'subj': {'name': '조제프 리우빌', 'pos': [44, 51], 'type': 'PS'},
#   'obj': {'name': '레온하르트 오일러', 'pos': [9, 18], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.5919625163078308},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subj': {'name': '초월수', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '리우빌 상수', 'pos': [24, 30], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.901602029800415},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 초월수의 예로서 다음과 같이 정의되는 리우빌 상수를 제시하였다.',
#   'subj': {'name': '리우빌 상수', 'pos': [24, 30], 'type': 'PS'},
#   'obj': {'name': '초월수', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.9002698063850403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '1900년에 다비트 힐베르트는 힐베르트의 23 문제 가운데 7번째 문제로 초월수에 대하여 다음과 같은 문제를 제시하였다.',
#   'subj': {'name': '다비트 힐베르트', 'pos': [7, 15], 'type': 'PS'},
#   'obj': {'name': '힐베르트', 'pos': [17, 21], 'type': 'PS'},
#   'description': '항목 주제에 영향을 준 것',
#   'confidence': 0.627402126789093},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subj': {'name': '이회창', 'pos': [37, 40], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [84, 87], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7903807163238525},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '16대 대선은 지난 15대 대선에서 간발의 차로 낙선하고 재도전한 이회창 한나라당 후보와 사상 최초의 국민 참여 경선을 통해 여당의 대통령 후보가 된 노무현 새천년민주당 후보의 양강 구도로 진행되었다.',
#   'subj': {'name': '노무현', 'pos': [84, 87], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [37, 40], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5989896655082703},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6149386167526245},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5337232351303101},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5488308668136597},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6421024203300476},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5574522614479065},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5329466462135315},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [75, 78], 'type': 'PS'},
#   'obj': {'name': '노사모', 'pos': [98, 101], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.6729810833930969},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '이회창', 'pos': [75, 78], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5330564975738525},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5594007968902588},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5612156987190247},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5412212014198303},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.837002158164978},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [8, 11], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6452248096466064},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6507483124732971},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '대선 재수생인 이회창 후보는 경험이나 세력 면에서 노무현 후보보다 대권 고지에 좀 더 유리할 것으로 점쳐졌으나, 이전 대선부터 불거진 이회창 후보의 두 아들의 병역기피 논란, 노사모를 비롯한 네티즌들의 열성적인 노무현 지지, 정몽준 후보와의 단일화 성공 등에 힘입어 노무현 후보가 당선되었다.',
#   'subj': {'name': '노무현', 'pos': [149, 152], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [126, 129], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8399055600166321},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '새천년민주당은 3월 9일부터 4월 27일까지 한국 정당 역사상 최초로 국민 참여 경선을 실시하고 과반 득표자인 노무현 전 해양수산부 장관을 대통령 후보로 선출하였다.',
#   'subj': {'name': '새천년민주당', 'pos': [0, 6], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [25, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8249130249023438},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '새천년민주당은 3월 9일부터 4월 27일까지 한국 정당 역사상 최초로 국민 참여 경선을 실시하고 과반 득표자인 노무현 전 해양수산부 장관을 대통령 후보로 선출하였다.',
#   'subj': {'name': '해양수산부', 'pos': [68, 73], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [25, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6931378245353699},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 박근혜 부총재는 2월 28일 이회창 총재의 리더십을 비판하며 한나라당을 탈당하였으며, 이후 신당을 창당하여 독자적으로 대선에 출마할 뜻을 밝혔다.',
#   'subj': {'name': '박근혜', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [20, 23], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7769392132759094},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 박근혜 부총재는 2월 28일 이회창 총재의 리더십을 비판하며 한나라당을 탈당하였으며, 이후 신당을 창당하여 독자적으로 대선에 출마할 뜻을 밝혔다.',
#   'subj': {'name': '이회창', 'pos': [20, 23], 'type': 'PS'},
#   'obj': {'name': '박근혜', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.5210031867027283},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제16대 대선은 민주당의 노무현 후보와 한나라당의 이회창 후보, 두 후보의 양자 대결 구도로 진행되어, 1971년 제7대 대선 이후 최초로 3자, 4자가 아닌 양자 구도로 치러진 대선이 되었다.',
#   'subj': {'name': '노무현', 'pos': [14, 17], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [28, 31], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.512476921081543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '제16대 대선은 민주당의 노무현 후보와 한나라당의 이회창 후보, 두 후보의 양자 대결 구도로 진행되어, 1971년 제7대 대선 이후 최초로 3자, 4자가 아닌 양자 구도로 치러진 대선이 되었다.',
#   'subj': {'name': '이회창', 'pos': [28, 31], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [14, 17], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7836214900016785},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 제15대 대선에서 패한 후 차근차근 대권 재도전을 준비해오던 이회창 후보가 한나라당을 완전히 장악하고 있었던 것과 달리, 진보 성향 인사이면서 보수 정당 민주당의 후보가 된 노무현 후보는 끊임없이 당 내부에서 공격을 받고 있었다.',
#   'subj': {'name': '이회창', 'pos': [38, 41], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [101, 104], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8392730355262756},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 제15대 대선에서 패한 후 차근차근 대권 재도전을 준비해오던 이회창 후보가 한나라당을 완전히 장악하고 있었던 것과 달리, 진보 성향 인사이면서 보수 정당 민주당의 후보가 된 노무현 후보는 끊임없이 당 내부에서 공격을 받고 있었다.',
#   'subj': {'name': '노무현', 'pos': [101, 104], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [38, 41], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8668186664581299},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': "이같은 상황에서 이회창의 당선이 유력시되고 있었으나, 제15대 대선과 마찬가지로 아들 병역기피 의혹에 시달리며 난관에 봉착한데다 노무현 후보가 이른바 '노풍'을 일으키며 선풍적 인기를 끌어 승패를 예측할 수 없게 되었다.",
#   'subj': {'name': '이회창', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [72, 75], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7270421385765076},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6164760589599609},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [47, 50], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7273812294006348},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '또한 노무현 후보는 정몽준 통합21 후보와 극적으로 단일화에 성공, 이를 발판 삼아 이회창 후보의 지지율을 맹추격했다.',
#   'subj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6392078399658203},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
# ...
#   'confidence': 0.7147538065910339},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현의 낙마를 바라는 의원들이 탈당하여 후보 단일화 추진 협의회(후단협)를 만들고 후보 단일화를 주장했는데, 이들은 노무현으로 후보 단일화가 되면 함께 할 수 없다고 발언하였고 정몽준 지지의 속내를 감추지 않았다.',
#   'subj': {'name': '정몽준', 'pos': [100, 103], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [66, 69], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7422971725463867},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '정몽준', 'pos': [3, 6], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8403524160385132},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '김민석', 'pos': [24, 27], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6734470129013062},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이때 정몽준의 국민통합21에 입당하기 위한 김민석의 탈당은 노무현에게 반전의 계기가 되었다.',
#   'subj': {'name': '노무현', 'pos': [33, 36], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [3, 6], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5250436067581177},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이 중 협상 담판은 정몽준의 후보의 주장으로 11월 1일에 정식 제안했고, 국민 경선안은 국민 참여 50%, 당원 참여 50%의 민주당 안을 노무현 후보가 11월 3일 정식 제안했다.',
#   'subj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [79, 82], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.824262261390686},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '이 중 협상 담판은 정몽준의 후보의 주장으로 11월 1일에 정식 제안했고, 국민 경선안은 국민 참여 50%, 당원 참여 50%의 민주당 안을 노무현 후보가 11월 3일 정식 제안했다.',
#   'subj': {'name': '노무현', 'pos': [79, 82], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8907572031021118},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7680083513259888},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [23, 26], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5549456477165222},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [11, 14], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5797938704490662},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 판세는 1강(이회창) 2중(노무현-정몽준)의 구도로 바뀌고 있던 차였다.',
#   'subj': {'name': '정몽준', 'pos': [23, 26], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6543811559677124},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '민주당 김원기 고문은 노무현의 결단은 "이기고 지는 것을 초월한 것"이라고 말했다.',
#   'subj': {'name': '노무현', 'pos': [12, 15], 'type': 'PS'},
#   'obj': {'name': '김원기', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5511898994445801},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6118833422660828},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.744867742061615},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '단일화가 되고 나서 여론 조사에서 노무현이 이회창 후보를 역전한 직후 이인제가 탈당하여 자유민주연합에 입당한 후 이회창을 지지하는 선언을 하는 등 새로운 갈등을 야기하기도 하였다.',
#   'subj': {'name': '이인제', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [63, 66], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.6895789504051208},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subj': {'name': '국민통합21', 'pos': [57, 63], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [29, 31], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5473567843437195},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '지지 철회 발표문에 따르면, 노무현 후보가 \'미국과 북한과 싸우면 우리가 말린다\'라는 표현을 했는데, 국민통합21은 "미국은 우리를 도와주는 우방이고, 미국이 북한과 싸울 이유가 없다는 시각을 가지고 있다"면서 이 발언을 문제 삼았다.',
#   'subj': {'name': '국민통합21', 'pos': [57, 63], 'type': 'OG'},
#   'obj': {'name': '북한', 'pos': [89, 91], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7592833638191223},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5100516080856323},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현 후보는 설득을 위해 심야에 정몽준 국민통합21 대표의 자택을 방문하였다.',
#   'subj': {'name': '정몽준', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.580996036529541},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [44, 47], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5452288389205933},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 정대철 선대위원장 등과 함께 자택 앞에서 기자들에 둘러싸여 기다렸으나 정몽준 대표는 만나주지 않았고, 심야 회동은 결렬되었다.',
#   'subj': {'name': '정몽준', 'pos': [44, 47], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6628365516662598},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '정몽준', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8826789259910583},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '진영이', 'pos': [26, 29], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6058288812637329},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그러나 정몽준의 지지철회로 위기감을 느낀 진보 진영이 민주노동당을 지지하지 않고 노무현에게 표를 몰아주는 의외의 효과가 나타난다.',
#   'subj': {'name': '노무현', 'pos': [45, 48], 'type': 'PS'},
#   'obj': {'name': '정몽준', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.7112634181976318},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '이회창', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5892874598503113},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '노무현은 2002년 12월 19일 대통령 선거에서 역전극을 반복하다가 한나라당의 이회창 후보를 57만 표 차로 이기고 당선됐다.',
#   'subj': {'name': '이회창', 'pos': [45, 48], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7581726312637329},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '참여정부를 표방하며 이듬해인 2003년 2월 25일 대한민국 제16대 대통령으로 취임하였다.',
#   'subj': {'name': '참여정부', 'pos': [0, 4], 'type': 'PS'},
#   'obj': {'name': '대한민국', 'pos': [29, 33], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6937259435653687},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '노무현', 'pos': [5, 8], 'type': 'PS'},
#   'obj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5016028881072998},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '노무현', 'pos': [10, 13], 'type': 'PS'},
#   'obj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6034039855003357},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [5, 8], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.605813205242157},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '취임 초 노무현은 노무현 정부, 즉 참여정부의 주요 정책은 크게 12개의 국정 과제로 제시됐다.',
#   'subj': {'name': '참여정부', 'pos': [20, 24], 'type': 'PS'},
#   'obj': {'name': '노무현', 'pos': [10, 13], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7317409515380859},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '루마니아', 'pos': [14, 18], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5994683504104614},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '핀란드', 'pos': [20, 23], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.584924042224884},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '핀란드', 'pos': [20, 23], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5499873757362366},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '영국', 'pos': [25, 27], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6270213723182678},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '영국', 'pos': [25, 27], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5782867074012756},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '스페인', 'pos': [29, 32], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.58428955078125},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '스페인', 'pos': [29, 32], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5696247816085815},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6571064591407776},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5755944848060608},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '러시아', 'pos': [51, 54], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6122260093688965},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '러시아', 'pos': [51, 54], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.591923713684082},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '프랑스', 'pos': [56, 59], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.537567138671875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '폴란드', 'pos': [61, 64], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6314495801925659},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '폴란드', 'pos': [61, 64], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6069628000259399},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '이탈리아', 'pos': [66, 70], 'type': 'LC'},
#   'obj': {'name': '동남아시아', 'pos': [40, 45], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5105699896812439},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0001.json',
#   'sentence': '그는 대표적으로 그리스, 루마니아, 핀란드, 영국, 스페인 국빈 방문과 동남아시아, 남미, 러시아, 프랑스, 폴란드, 이탈리아, 바티칸 순방을 위한 23차례에 걸쳐 총 49개국을 방문했다.',
#   'subj': {'name': '이탈리아', 'pos': [66, 70], 'type': 'LC'},
#   'obj': {'name': '남미', 'pos': [47, 49], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5640079379081726},
#  ...]

# %%
dev_data
# Out:
# [{'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '김철', 'pos': [6, 8], 'type': 'PS'},
#   'obj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.510070264339447},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '김철', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6147775650024414},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '북문안교회', 'pos': [14, 19], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.7553680539131165},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '광주제일교회', 'pos': [22, 28], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.6122999787330627},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7108108401298523},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6520150899887085},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'obj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.650454044342041},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '김철', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6675763130187988},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '북문안교회', 'pos': [14, 19], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.7811994552612305},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '광주제일교회', 'pos': [22, 28], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.6360031366348267},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.748222291469574},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6514558792114258},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'obj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6855943202972412},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '김철', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6050668358802795},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '북문안교회', 'pos': [14, 19], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.7666805386543274},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '광주제일교회', 'pos': [22, 28], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.6083980202674866},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5733534097671509},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7094047665596008},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8680047392845154},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '김철', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5935593247413635},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '북문안교회', 'pos': [14, 19], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.8061964511871338},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '광주제일교회', 'pos': [22, 28], 'type': 'OG'},
#   'description': '항목 주제인 사람, 단체 또는 종교적 건물과 연관된 종교',
#   'confidence': 0.651695728302002},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '강석봉', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5798312425613403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '姜錫峰', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7466928362846375},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '광주시위는 김철의 주도로 북문안교회(현,광주제일교회)의 교인들 강석봉(姜錫峰/후일 제3차 조선공산당 전남책임비서),한길상(韓吉祥/제4차 조선공산당사건으로 옥고/전남건국준비위원회 산업부장)등과 항일 비밀조직이었던 삼합(三合)양조회 회원들을 중심으로 숭일학교, 수피아여학교, 농업학교등 학생들이 참여하였다.',
#   'subj': {'name': '韓吉祥', 'pos': [68, 71], 'type': 'PS'},
#   'obj': {'name': '한길상', 'pos': [64, 67], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8715017437934875},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종이 3년형을 마치고 대구형무소에서 1922년 출감하는 날 Eugene Bell 선교사가 대구까지 찾아가 그를 맞이했다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '대구형무소', 'pos': [14, 19], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6040080785751343},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종이 3년형을 마치고 대구형무소에서 1922년 출감하는 날 Eugene Bell 선교사가 대구까지 찾아가 그를 맞이했다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': 'Eugene Bell', 'pos': [35, 46], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5965700149536133},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종이 3년형을 마치고 대구형무소에서 1922년 출감하는 날 Eugene Bell 선교사가 대구까지 찾아가 그를 맞이했다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '대구', 'pos': [52, 54], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6281492114067078},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종이 3년형을 마치고 대구형무소에서 1922년 출감하는 날 Eugene Bell 선교사가 대구까지 찾아가 그를 맞이했다.',
#   'subj': {'name': 'Eugene Bell', 'pos': [35, 46], 'type': 'PS'},
#   'obj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5055374503135681},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종이 3년형을 마치고 대구형무소에서 1922년 출감하는 날 Eugene Bell 선교사가 대구까지 찾아가 그를 맞이했다.',
#   'subj': {'name': 'Eugene Bell', 'pos': [35, 46], 'type': 'PS'},
#   'obj': {'name': '대구', 'pos': [52, 54], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.554527759552002},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence':

#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1927년 2월 서울에서 이상재(李商在), 안재홍(安在鴻), 권동진(權東鎭)등의 주도로 민족주의자와 사회주의자들이 통합한 민족유일당 신간회가 창립되자, 광주에서도 신간회 광주지회가 1927년 10월 결성되었는데 신간회에 참여한 좌우익 모든 정파로 부터 최흥종이 초대회장으로 추대되었다.',
#   'subj': {'name': '權東鎭', 'pos': [38, 41], 'type': 'PS'},
#   'obj': {'name': '권동진', 'pos': [34, 37], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5215668678283691},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1927년 2월 서울에서 이상재(李商在), 안재홍(安在鴻), 권동진(權東鎭)등의 주도로 민족주의자와 사회주의자들이 통합한 민족유일당 신간회가 창립되자, 광주에서도 신간회 광주지회가 1927년 10월 결성되었는데 신간회에 참여한 좌우익 모든 정파로 부터 최흥종이 초대회장으로 추대되었다.',
#   'subj': {'name': '權東鎭', 'pos': [38, 41], 'type': 'PS'},
#   'obj': {'name': '광주', 'pos': [85, 87], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6307745575904846},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1927년 2월 서울에서 이상재(李商在), 안재홍(安在鴻), 권동진(權東鎭)등의 주도로 민족주의자와 사회주의자들이 통합한 민족유일당 신간회가 창립되자, 광주에서도 신간회 광주지회가 1927년 10월 결성되었는데 신간회에 참여한 좌우익 모든 정파로 부터 최흥종이 초대회장으로 추대되었다.',
#   'subj': {'name': '최흥종', 'pos': [141, 144], 'type': 'PS'},
#   'obj': {'name': '서울', 'pos': [9, 11], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7545555233955383},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1927년 2월 서울에서 이상재(李商在), 안재홍(安在鴻), 권동진(權東鎭)등의 주도로 민족주의자와 사회주의자들이 통합한 민족유일당 신간회가 창립되자, 광주에서도 신간회 광주지회가 1927년 10월 결성되었는데 신간회에 참여한 좌우익 모든 정파로 부터 최흥종이 초대회장으로 추대되었다.',
#   'subj': {'name': '최흥종', 'pos': [141, 144], 'type': 'PS'},
#   'obj': {'name': '이상재', 'pos': [14, 17], 'type': 'PS'},
#   'description': '항목 주제의 부통령 혹은 총리',
#   'confidence': 0.5889382362365723},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1927년 2월 서울에서 이상재(李商在), 안재홍(安在鴻), 권동진(權東鎭)등의 주도로 민족주의자와 사회주의자들이 통합한 민족유일당 신간회가 창립되자, 광주에서도 신간회 광주지회가 1927년 10월 결성되었는데 신간회에 참여한 좌우익 모든 정파로 부터 최흥종이 초대회장으로 추대되었다.',
#   'subj': {'name': '최흥종', 'pos': [141, 144], 'type': 'PS'},
#   'obj': {'name': '광주', 'pos': [85, 87], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7426691055297852},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '부회장은 정수태(丁秀泰/전 국방장관, 국회의장 정래혁의 부친)였다.',
#   'subj': {'name': '정수태', 'pos': [5, 8], 'type': 'PS'},
#   'obj': {'name': '丁秀泰', 'pos': [9, 12], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.8863475918769836},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '부회장은 정수태(丁秀泰/전 국방장관, 국회의장 정래혁의 부친)였다.',
#   'subj': {'name': '丁秀泰', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': '정수태', 'pos': [5, 8], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.6536900401115417},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '부회장은 정수태(丁秀泰/전 국방장관, 국회의장 정래혁의 부친)였다.',
#   'subj': {'name': '정래혁', 'pos': [26, 29], 'type': 'PS'},
#   'obj': {'name': '정수태', 'pos': [5, 8], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6108056902885437},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '그러나 정치활동은 그가 뜻한바가 아니어서 2년후 1929년 정수태에게 신간회 광주지회장 자리를 넘기고, 최흥종은 제중병원(원장 Wilson 의사)에 찾아오는 한센병환자들을 돌보는 일에 전념한다.',
#   'subj': {'name': '최흥종', 'pos': [58, 61], 'type': 'PS'},
#   'obj': {'name': '정수태', 'pos': [33, 36], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.6633481979370117},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': '최흥종', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': 'Elizabeth', 'pos': [46, 55], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5715806484222412},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': '최흥종', 'pos': [9, 12], 'type': 'PS'},
#   'obj': {'name': '.Shepping', 'pos': [57, 66], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.6092851161956787},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': 'Elizabeth', 'pos': [46, 55], 'type': 'PS'},
#   'obj': {'name': '최흥종', 'pos': [9, 12], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5937241911888123},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': 'Elizabeth', 'pos': [46, 55], 'type': 'PS'},
#   'obj': {'name': '.Shepping', 'pos': [57, 66], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.7050343155860901},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': '.Shepping', 'pos': [57, 66], 'type': 'PS'},
#   'obj': {'name': '최흥종', 'pos': [9, 12], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.6269217729568481},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '이 제중병원에는 최흥종과 함께 한센병 환자들을 돌보는 일에 전념한 사람이 있었으니 Elizabeth J.Shepping(한국이름 서서평)(여)(1923년부터 초대-10대 조선간호부협회 회장/1934년 사망)선교사였다.',
#   'subj': {'name': '.Shepping', 'pos': [57, 66], 'type': 'PS'},
#   'obj': {'name': 'Elizabeth', 'pos': [46, 55], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5863732695579529},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '서울', 'pos': [7, 9], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.641542375087738},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.7807176113128662},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '尹致昊', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.6861447691917419},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7517147064208984},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '송진우', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7602611780166626},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '최원순', 'pos': [99, 102], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.573458194732666},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.5488412976264954},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6535354852676392},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '송진우', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8233018517494202},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '宋鎭禹', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5065163373947144},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '안재홍', 'pos': [45, 48], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.5690854787826538},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
#   'obj': {'name': '서정희', 'pos': [78, 81], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5547693371772766},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '尹致昊', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5637165904045105},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '尹致昊', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '金炳魯', 'pos': [29, 32], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5130071640014648},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '尹致昊', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '송진우', 'pos': [35, 38], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6868587732315063},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '尹致昊', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '宋鎭禹', 'pos': [39, 42], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5747606754302979},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'obj': {'name': '최흥종', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8388797640800476},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'obj': {'name': '서울', 'pos': [7, 9], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7774296998977661},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '최흥종은 곧 서울로 올라와 윤치호(尹致昊), 김병로(金炳魯), 송진우(宋鎭禹), 안재홍, 김성수(金性洙), 조병옥(趙炳玉), 이인(李仁), 서정희(徐廷禧/노동공제회 초대회장), 최원순(崔元淳/당시 동아일보 편집국장)등을 찾아 취지를 설명하였다.',
#   'subj': {'name': '김병로', 'pos': [25, 28], 'type': 'PS'},
#   'obj': {'name': '윤치호', 'pos': [15, 18], 'type': 'PS'},
# ...
#   'confidence': 0.5952260494232178},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '2004년 하계 올림픽 아프가니스탄 선수단은 그리스 아테네에서 개최된 2004년 하계 올림픽에 참가한 올림픽 아프가니스탄 선수단이다.',
#   'subj': {'name': '아프가니스탄 선수단', 'pos': [61, 71], 'type': 'OG'},
#   'obj': {'name': '그리스', 'pos': [25, 28], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.9176110029220581},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '2004년 하계 올림픽 아프가니스탄 선수단은 그리스 아테네에서 개최된 2004년 하계 올림픽에 참가한 올림픽 아프가니스탄 선수단이다.',
#   'subj': {'name': '아프가니스탄 선수단', 'pos': [61, 71], 'type': 'OG'},
#   'obj': {'name': '아테네', 'pos': [29, 32], 'type': 'LC'},
#   'description': '항목 주제가 위치한 행정 구역',
#   'confidence': 0.7055155038833618},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence':

#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '한국실업야구연맹(韓國實業野球聯盟, Korea Amature Baseball Association, KABA)은 야구선수 진로개척 차원의 취업 지원을 통해 한국야구의 지속적인 발전을 뒷받침하기 위해 설립된 대한야구소프트볼협회 산하 준가맹 단체이다.',
#   'subj': {'name': 'Korea', 'pos': [19, 24], 'type': 'OG'},
#   'obj': {'name': 'KABA', 'pos': [55, 59], 'type': 'OG'},
#   'description': '항목 주제인 팀이 출전한 리그',
#   'confidence': 0.9019485116004944},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '한국실업야구연맹(韓國實業野球聯盟, Korea Amature Baseball Association, KABA)은 야구선수 진로개척 차원의 취업 지원을 통해 한국야구의 지속적인 발전을 뒷받침하기 위해 설립된 대한야구소프트볼협회 산하 준가맹 단체이다.',
#   'subj': {'name': 'Korea', 'pos': [19, 24], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [86, 88], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8196311593055725},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '한국실업야구연맹(韓國實業野球聯盟, Korea Amature Baseball Association, KABA)은 야구선수 진로개척 차원의 취업 지원을 통해 한국야구의 지속적인 발전을 뒷받침하기 위해 설립된 대한야구소프트볼협회 산하 준가맹 단체이다.',
#   'subj': {'name': 'KABA', 'pos': [55, 59], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [86, 88], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.839091956615448},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '한국실업야구연맹(韓國實業野球聯盟, Korea Amature Baseball Association, KABA)은 야구선수 진로개척 차원의 취업 지원을 통해 한국야구의 지속적인 발전을 뒷받침하기 위해 설립된 대한야구소프트볼협회 산하 준가맹 단체이다.',
#   'subj': {'name': '대한야구소프트볼협회', 'pos': [114, 124], 'type': 'OG'},
#   'obj': {'name': '한국', 'pos': [86, 88], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8153910636901855},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '1946년 아마야구 전신 단체가 출범 후, 성인야구 업무를 관장하는 독립 단체로 유지되어 오다 1979년 세계야구선수권대회 서울 유치가 확정되자 야구계 발전을 위해 대한야구협회에 자동 통합되기도 했으나 야구선수 취업난 해소에 대한 필요성이 강조되며 2011년 1월 19일 대한야구협회로부터 산하 준회원 단체 승인을 받았다.',
#   'subj': {'name': '대한야구협회', 'pos': [152, 158], 'type': 'OG'},
#   'obj': {'name': '서울', 'pos': [69, 71], 'type': 'LC'},
#   'description': '항목 주제가 위치한 행정 구역',
#   'confidence': 0.5747278332710266},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '서구', 'pos': [17, 19], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6543105840682983},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '강남구', 'pos': [54, 57], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.7670689225196838},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '논현동', 'pos': [58, 61], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.7218313217163086},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '서울시', 'pos': [95, 98], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5000677108764648},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '양천구', 'pos': [99, 102], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.7704486846923828},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '연맹', 'pos': [0, 2], 'type': 'OG'},
#   'obj': {'name': '목동', 'pos': [103, 105], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6623808145523071},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0235.json',
#   'sentence': '연맹 본부 소재지는 대전광역시 서구 계룡로 314번지(갈마동) 대전일보사이며 사무국은 서울특별시 강남구 논현동 82-18번지 벤쳐캐슬빌딩에 위치하고 있으며 연락 사무소는 서울시 양천구 목동 914번지 목동야구장(3루 데크쪽)에 확보하고 있다.',
#   'subj': {'name': '대전광역시', 'pos': [11, 16], 'type': 'LC'},
#   'obj': {'name': '서울특별시', 'pos': [48, 53], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5237633585929871},
#  ...]

# %%
test_data
# Out:
# [{'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '레이스베이크()는 네덜란드 서부 자위트홀란트주의 도시로 면적은 107.16km, 높이는 3m, 인구는 76,959명(2014년 5월 기준), 인구 밀도는 723명/km이다.',
#   'subj': {'name': '레이스베이크', 'pos': [0, 6], 'type': 'LC'},
#   'obj': {'name': '자위트홀란트주', 'pos': [18, 25], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.8524457812309265},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '레이스베이크()는 네덜란드 서부 자위트홀란트주의 도시로 면적은 107.16km, 높이는 3m, 인구는 76,959명(2014년 5월 기준), 인구 밀도는 723명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [10, 14], 'type': 'LC'},
#   'obj': {'name': '자위트홀란트주', 'pos': [18, 25], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.9024604558944702},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '루르몬트()는 네덜란드 남동부 림뷔르흐주의 도시로 면적은 71.10km, 높이는 22m, 인구는 57,044명(2014년 5월 기준), 인구 밀도는 938명/km이다.',
#   'subj': {'name': '루르몬트', 'pos': [0, 4], 'type': 'LC'},
#   'obj': {'name': '림뷔르흐주', 'pos': [17, 22], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.9095008969306946},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '루르몬트()는 네덜란드 남동부 림뷔르흐주의 도시로 면적은 71.10km, 높이는 22m, 인구는 57,044명(2014년 5월 기준), 인구 밀도는 938명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [8, 12], 'type': 'LC'},
#   'obj': {'name': '루르몬트', 'pos': [0, 4], 'type': 'LC'},
#   'description': '항목 주제인 지방 정부나 중앙 정부가 위치한 도시/자치도시',
#   'confidence': 0.5329780578613281},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '루르몬트()는 네덜란드 남동부 림뷔르흐주의 도시로 면적은 71.10km, 높이는 22m, 인구는 57,044명(2014년 5월 기준), 인구 밀도는 938명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [8, 12], 'type': 'LC'},
#   'obj': {'name': '림뷔르흐주', 'pos': [17, 22], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.861701488494873},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '뫼즈 강 동안과 접하며 동쪽으로는 독일과 국경을 접한다.',
#   'subj': {'name': '독일', 'pos': [19, 21], 'type': 'LC'},
#   'obj': {'name': '뫼즈 강', 'pos': [0, 4], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6332795023918152},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '호른()은 네덜란드 노르트홀란트주의 도시로 면적은 53.25km, 높이는 −1m, 인구는 71,888명(2014년 5월 기준), 인구 밀도는 3,550명/km이다.',
#   'subj': {'name': '호른', 'pos': [0, 2], 'type': 'LC'},
#   'obj': {'name': '노르트홀란트주의', 'pos': [11, 19], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.6610287427902222},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '호른()은 네덜란드 노르트홀란트주의 도시로 면적은 53.25km, 높이는 −1m, 인구는 71,888명(2014년 5월 기준), 인구 밀도는 3,550명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [6, 10], 'type': 'LC'},
#   'obj': {'name': '호른', 'pos': [0, 2], 'type': 'LC'},
#   'description': '항목 주제인 지방 정부나 중앙 정부가 위치한 도시/자치도시',
#   'confidence': 0.5571966767311096},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '호프도르프()는 네덜란드 노르트홀란트주의 도시로 인구는 73,000명(2009년 기준)이다.',
#   'subj': {'name': '호프도르프', 'pos': [0, 5], 'type': 'LC'},
#   'obj': {'name': '노르트홀란트', 'pos': [14, 20], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.648306131362915},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '호프도르프()는 네덜란드 노르트홀란트주의 도시로 인구는 73,000명(2009년 기준)이다.',
#   'subj': {'name': '네덜란드', 'pos': [9, 13], 'type': 'LC'},
#   'obj': {'name': '호프도르프', 'pos': [0, 5], 'type': 'LC'},
#   'description': '항목 주제인 지방 정부나 중앙 정부가 위치한 도시/자치도시',
#   'confidence': 0.5096350312232971},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '팔스()는 네덜란드 남동부 림뷔르흐주의 도시로 면적은 23.87km, 높이는 200m, 인구는 9,691명(2014년 5월 기준), 인구 밀도는 406명/km이다.',
#   'subj': {'name': '팔스', 'pos': [0, 2], 'type': 'LC'},
#   'obj': {'name': '림뷔르흐주', 'pos': [15, 20], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.8226044178009033},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '팔스()는 네덜란드 남동부 림뷔르흐주의 도시로 면적은 23.87km, 높이는 200m, 인구는 9,691명(2014년 5월 기준), 인구 밀도는 406명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [6, 10], 'type': 'LC'},
#   'obj': {'name': '림뷔르흐주', 'pos': [15, 20], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.858797013759613},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '하야마 쇼노(, 1995년 12월 19일 ~ )는, 일본의 배우이다.',
#   'subj': {'name': '하야마 쇼노', 'pos': [0, 6], 'type': 'PS'},
#   'obj': {'name': '일본', 'pos': [29, 31], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7986496090888977},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '리사 마틴-온디에키(Lisa Martin-Ondieki, 1960년 5월 12일 ~ )는 전 오스트레일리아의 마라톤 선수로 1988년 서울 올림픽 은메달리스트이다.',
#   'subj': {'name': '리사 마틴', 'pos': [0, 5], 'type': 'PS'},
#   'obj': {'name': '오스트레일리아', 'pos': [52, 59], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5747362375259399},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '리사 마틴-온디에키(Lisa Martin-Ondieki, 1960년 5월 12일 ~ )는 전 오스트레일리아의 마라톤 선수로 1988년 서울 올림픽 은메달리스트이다.',
#   'subj': {'name': '온디에키', 'pos': [6, 10], 'type': 'PS'},
#   'obj': {'name': '오스트레일리아', 'pos': [52, 59], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7629130482673645},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '리사 마틴-온디에키(Lisa Martin-Ondieki, 1960년 5월 12일 ~ )는 전 오스트레일리아의 마라톤 선수로 1988년 서울 올림픽 은메달리스트이다.',
#   'subj': {'name': 'Lisa Martin-Ondieki', 'pos': [11, 30], 'type': 'PS'},
#   'obj': {'name': '오스트레일리아', 'pos': [52, 59], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8511794209480286},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '사우스오스트레일리아주 골리에서 태어난 마틴은 1984년부터 1996년까지 4개의 하계 올림픽에 참가하여, 3번째 올림픽에서 은메달을 따면서 자신 세대의 최고 거리 달리기 선수들 중의 하나로 자신의 지위를 확정시켰다.',
#   'subj': {'name': '마틴', 'pos': [21, 23], 'type': 'PS'},
#   'obj': {'name': '사우스오스트레일리아주', 'pos': [0, 11], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.5655229091644287},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '사우스오스트레일리아주 골리에서 태어난 마틴은 1984년부터 1996년까지 4개의 하계 올림픽에 참가하여, 3번째 올림픽에서 은메달을 따면서 자신 세대의 최고 거리 달리기 선수들 중의 하나로 자신의 지위를 확정시켰다.',
#   'subj': {'name': '마틴', 'pos': [21, 23], 'type': 'PS'},
#   'obj': {'name': '골리', 'pos': [12, 14], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.6746567487716675},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '스테이터스 쿠오()는 영국의 록 밴드이다.',
#   'subj': {'name': '스테이터스 쿠오', 'pos': [0, 8], 'type': 'PS'},
#   'obj': {'name': '영국', 'pos': [12, 14], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8624550104141235},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '프랜시스 로시와 앨런 랭커스터가 학창시절 결성한 밴드 더 스펙터스()에서 시작했으며, 특유의 부기 록 음악으로 꾸준히 활동하며 사랑받았다.',
#   'subj': {'name': '프랜시스 로시', 'pos': [0, 7], 'type': 'PS'},
#   'obj': {'name': '앨런 랭커스터', 'pos': [9, 16], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.555706799030304},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '프랜시스 로시와 앨런 랭커스터가 학창시절 결성한 밴드 더 스펙터스()에서 시작했으며, 특유의 부기 록 음악으로 꾸준히 활동하며 사랑받았다.',
#   'subj': {'name': '앨런 랭커스터', 'pos': [9, 16], 'type': 'PS'},
#   'obj': {'name': '프랜시스 로시', 'pos': [0, 7], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.687480628490448},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '하를레메르메이르()는 네덜란드 노르트홀란트주의 도시로 면적은 185.29km, 높이는 −4m, 인구는 144,226명(2014년 5월 기준), 인구 밀도는 807명/km이다.',
#   'subj': {'name': '하를레메르메이르', 'pos': [0, 8], 'type': 'PS'},
#   'obj': {'name': '네덜란드', 'pos': [12, 16], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.9231754541397095},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '2×2 행렬군으로, 또는 실수 선형 분수 변환군으로, 또는 3차원 민코프스키 공간의 로런츠 군으로 여길 수 있다.',
#   'subj': {'name': '민코프스키', 'pos': [37, 42], 'type': 'LC'},
#   'obj': {'name': '로런츠', 'pos': [47, 50], 'type': 'LC'},
#   'description': '항목 주제가 알려진 일, 역사적인 사건 등. 사람, 조직, 집중력 캠프 등',
#   'confidence': 0.6105803847312927},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이아마미후아미(iamamiwhoami)는 스웨덴의 전자 음악 프로젝트 그룹이다.',
#   'subj': {'name': '이아마미후아미', 'pos': [0, 7], 'type': 'PS'},
#   'obj': {'name': '스웨덴', 'pos': [23, 26], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5968518853187561},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이아마미후아미(iamamiwhoami)는 스웨덴의 전자 음악 프로젝트 그룹이다.',
#   'subj': {'name': 'iamamiwhoami', 'pos': [8, 20], 'type': 'PS'},
#   'obj': {'name': '스웨덴', 'pos': [23, 26], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6669943332672119},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '재니스 "잰"셔카우스키(, 1944년 5월 26일 ~ )는 미국 민주당 소속의 정치인이다.',
#   'subj': {'name': '재니스', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [33, 35], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7840417623519897},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '재니스 "잰"셔카우스키(, 1944년 5월 26일 ~ )는 미국 민주당 소속의 정치인이다.',
#   'subj': {'name': '잰', 'pos': [5, 6], 'type': 'PS'},
#   'obj': {'name': '미국', 'pos': [33, 35], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6821381449699402},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '조영인', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '조영심', 'pos': [54, 57], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5634874701499939},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '조영인', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '趙永心', 'pos': [58, 61], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8171578049659729},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '趙永仁', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '조영심', 'pos': [54, 57], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5191245675086975},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '趙永仁', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '趙永心', 'pos': [58, 61], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7300928831100464},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '조영심', 'pos': [54, 57], 'type': 'PS'},
#   'obj': {'name': '조영인', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.528576672077179},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '조영심', 'pos': [54, 57], 'type': 'PS'},
#   'obj': {'name': '趙永心', 'pos': [58, 61], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7079944014549255},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '趙永心', 'pos': [58, 61], 'type': 'PS'},
#   'obj': {'name': '조영인', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5924371480941772},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '조영인(趙永仁, 1133년 ~ 1202년)은 고려 중기의 문신으로, 본관은 횡천(橫川), 초명은 조영심(趙永心)이다.',
#   'subj': {'name': '趙永心', 'pos': [58, 61], 'type': 'PS'},
#   'obj': {'name': '조영심', 'pos': [54, 57], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8679513335227966},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1160년(의종 14) 과거에 급제하여 전주서기(全州書記)로 나가서는 선정으로 이름이 났으며, 명종이 즉위하자 조영인을 시켜 태자를 돌보게 했다.',
#   'subj': {'name': '의종', 'pos': [6, 8], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [53, 55], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.9460547566413879},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1160년(의종 14) 과거에 급제하여 전주서기(全州書記)로 나가서는 선정으로 이름이 났으며, 명종이 즉위하자 조영인을 시켜 태자를 돌보게 했다.',
#   'subj': {'name': '명종', 'pos': [53, 55], 'type': 'PS'},
#   'obj': {'name': '의종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5825707912445068},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1160년(의종 14) 과거에 급제하여 전주서기(全州書記)로 나가서는 선정으로 이름이 났으며, 명종이 즉위하자 조영인을 시켜 태자를 돌보게 했다.',
#   'subj': {'name': '명종', 'pos': [53, 55], 'type': 'PS'},
#   'obj': {'name': '조영인', 'pos': [62, 65], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6406984925270081},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1160년(의종 14) 과거에 급제하여 전주서기(全州書記)로 나가서는 선정으로 이름이 났으며, 명종이 즉위하자 조영인을 시켜 태자를 돌보게 했다.',
#   'subj': {'name': '조영인', 'pos': [62, 65], 'type': 'PS'},
#   'obj': {'name': '의종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.559230625629425},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1160년(의종 14) 과거에 급제하여 전주서기(全州書記)로 나가서는 선정으로 이름이 났으며, 명종이 즉위하자 조영인을 시켜 태자를 돌보게 했다.',
#   'subj': {'name': '조영인', 'pos': [62, 65], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [53, 55], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7131142020225525},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'obj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9224517941474915},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'obj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8028139472007751},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'obj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8431196212768555},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'obj': {'name': '금나라', 'pos': [41, 44], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.5122992396354675},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'obj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9324602484703064},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'obj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.853813886642456},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'obj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8585872650146484},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'obj': {'name': '금나라', 'pos': [41, 44], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.5551707744598389},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'obj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9121447205543518},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'obj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9195857048034668},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'obj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9235208034515381},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'obj': {'name': '최문목', 'pos': [118, 121], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9398277997970581},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'obj': {'name': '崔文牧', 'pos': [122, 125], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9273998737335205},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1174년(명종 4) 좌사원외랑(左司員外郞)으로서 정조사(正朝使)가 되어 금나라에 가서 신년을 하례하고 돌아왔으며, 그 후 여러 차례 승진해 1185년(명종 15) 우승선(右承宣)으로서 국자시(國子試)를 주관해 최문목(崔文牧), 정광우(丁光祐) 등을 선발했다.',
#   'subj': {'name': '丁光祐', 'pos': [132, 135], 'type': 'PS'},
#   'obj': {'name': '정광우', 'pos': [128, 131], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.9410542249679565},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1190년(명종 20) 동지추밀원사(同知樞密院使)로 승진해 재추의 반열에 들어갔으며, 이듬해 참지정사(叅知政事)·정당문학(政堂文學)·한림학사승지(翰林學士承旨)에 임명되었다가, 1194년(명종 24) 수태위(守太尉)·상주국(上柱國)이 더해졌다.',
#   'subj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [104, 106], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7775381803512573},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1190년(명종 20) 동지추밀원사(同知樞密院使)로 승진해 재추의 반열에 들어갔으며, 이듬해 참지정사(叅知政事)·정당문학(政堂文學)·한림학사승지(翰林學士承旨)에 임명되었다가, 1194년(명종 24) 수태위(守太尉)·상주국(上柱國)이 더해졌다.',
#   'subj': {'name': '명종', 'pos': [104, 106], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5484784245491028},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.9384469985961914},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'obj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8952140808105469},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '권판이', 'pos': [13, 16], 'type': 'PS'},
#   'obj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.6586429476737976},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '권판이', 'pos': [13, 16], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5481382608413696},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '권판이', 'pos': [13, 16], 'type': 'PS'},
#   'obj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.8154278993606567},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7173219323158264},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6657212376594543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'obj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'description': '항목 주제의 자녀',
#   'confidence': 0.6771916151046753},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.8724008798599243},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'obj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.6948428750038147},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'obj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5259585976600647},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'obj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6262736916542053},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.863585352897644},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'obj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.7114183306694031},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'obj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.6488901972770691},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [6, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6895142793655396},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'obj': {'name': '권판이', 'pos': [13, 16], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.7340526580810547},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'obj': {'name': '權判吏', 'pos': [19, 22], 'type': 'PS'},
#   'description': '항목 주제의 부모',
#   'confidence': 0.8283137083053589},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [38, 40], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.5751562714576721},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1196년(명종 26) 권판이부사(權判吏部事)를 겸직했다가, 이듬해 신종(神宗)이 즉위하자 수태사(守太師)·문하시랑평장사(門下侍郞平章事)·판이부사(判吏部事)로 승진했다.',
#   'subj': {'name': '판이', 'pos': [77, 79], 'type': 'PS'},
#   'obj': {'name': '神宗', 'pos': [41, 43], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.748832643032074},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1198년(신종 원년) 금나라 사신이 와서 명종이 왕위를 물려준 일에 대해 따지면서 “이 조서는 반드시 전 왕에게 직접 전달하라는 황제의 분부가 계셨소.”라고 하였다.',
#   'subj': {'name': '명종', 'pos': [24, 26], 'type': 'PS'},
#   'obj': {'name': '금나라', 'pos': [13, 16], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.550918698310852},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1198년(신종 원년) 금나라 사신이 와서 명종이 왕위를 물려준 일에 대해 따지면서 “이 조서는 반드시 전 왕에게 직접 전달하라는 황제의 분부가 계셨소.”라고 하였다.',
#   'subj': {'name': '전', 'pos': [58, 59], 'type': 'PS'},
#   'obj': {'name': '명종', 'pos': [24, 26], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5996962785720825},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이에 금나라 사신이 “정말 그렇다면 전 왕에게 꼭 직접 전달할 필요는 없소.”라며 이튿날 신종에게 조서를 전해 주었다.',
#   'subj': {'name': '금나라', 'pos': [3, 6], 'type': 'OG'},
#   'obj': {'name': '전', 'pos': [20, 21], 'type': 'PS'},
#   'description': '항목 주제의 지도자',
#   'confidence': 0.6529533267021179},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이에 금나라 사신이 “정말 그렇다면 전 왕에게 꼭 직접 전달할 필요는 없소.”라며 이튿날 신종에게 조서를 전해 주었다.',
#   'subj': {'name': '금나라', 'pos': [3, 6], 'type': 'OG'},
#   'obj': {'name': '신종', 'pos': [50, 52], 'type': 'PS'},
#   'description': '항목 주제의 지도자',
#   'confidence': 0.8769251108169556},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이에 금나라 사신이 “정말 그렇다면 전 왕에게 꼭 직접 전달할 필요는 없소.”라며 이튿날 신종에게 조서를 전해 주었다.',
#   'subj': {'name': '전', 'pos': [20, 21], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [50, 52], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.7472711205482483},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '졸하니', 'pos': [18, 21], 'type': 'PS'},
#   'obj': {'name': '문경', 'pos': [33, 35], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6523563861846924},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '졸하니', 'pos': [18, 21], 'type': 'PS'},
#   'obj': {'name': '文景', 'pos': [36, 38], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6948649287223816},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '졸하니', 'pos': [18, 21], 'type': 'PS'},
#   'obj': {'name': '신종', 'pos': [56, 58], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5102767944335938},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '신종', 'pos': [56, 58], 'type': 'PS'},
#   'obj': {'name': '졸하니', 'pos': [18, 21], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.553004264831543},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '신종', 'pos': [56, 58], 'type': 'PS'},
#   'obj': {'name': '문경', 'pos': [33, 35], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6908627152442932},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1202년(신종 5년) 70세로 졸하니 왕이 크게 애도하며 문경(文景)이라는 시호를 내렸으며, 뒷날 신종의 묘정에 배향되었다.',
#   'subj': {'name': '신종', 'pos': [56, 58], 'type': 'PS'},
#   'obj': {'name': '文景', 'pos': [36, 38], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7402705550193787},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '자켓 사진 (통상반 표지):이코마 리나·이토 마리카·이노우에 사유리·사쿠라이 레이카·마츠무라 사융리·와카츠키 유미',
#   'subj': {'name': '이노우에 사유리', 'pos': [29, 37], 'type': 'PS'},
#   'obj': {'name': '사쿠라이 레이카', 'pos': [38, 46], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.575238823890686},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '자켓 사진 (통상반 표지):이코마 리나·이토 마리카·이노우에 사유리·사쿠라이 레이카·마츠무라 사융리·와카츠키 유미',
#   'subj': {'name': '사쿠라이 레이카', 'pos': [38, 46], 'type': 'PS'},
#   'obj': {'name': '마츠무라 사융리', 'pos': [47, 55], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.6743029356002808},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '자켓 사진 (통상반 표지):이코마 리나·이토 마리카·이노우에 사유리·사쿠라이 레이카·마츠무라 사융리·와카츠키 유미',
#   'subj': {'name': '마츠무라 사융리', 'pos': [47, 55], 'type': 'PS'},
#   'obj': {'name': '사쿠라이 레이카', 'pos': [38, 46], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.7977108359336853},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '자켓 사진 (통상반 표지):이코마 리나·이토 마리카·이노우에 사유리·사쿠라이 레이카·마츠무라 사융리·와카츠키 유미',
#   'subj': {'name': '마츠무라 사융리', 'pos': [47, 55], 'type': 'PS'},
#   'obj': {'name': '와카츠키 유미', 'pos': [56, 63], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.5913748741149902},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '자켓 사진 (통상반 표지):이코마 리나·이토 마리카·이노우에 사유리·사쿠라이 레이카·마츠무라 사융리·와카츠키 유미',
#   'subj': {'name': '와카츠키 유미', 'pos': [56, 63], 'type': 'PS'},
#   'obj': {'name': '마츠무라 사융리', 'pos': [47, 55], 'type': 'PS'},
#   'description': '항목 주제인 인물의 배우자 (동거인의 개념은 아님)',
#   'confidence': 0.578747034072876},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '유영훈(劉永勳, 1955년 4월 30일 ~ )은 대한민국 기초단체장이자 제36·37·38대 충청북도 진천군수이다.',
#   'subj': {'name': '유영훈', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '劉永勳', 'pos': [4, 7], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8597816824913025},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '유영훈(劉永勳, 1955년 4월 30일 ~ )은 대한민국 기초단체장이자 제36·37·38대 충청북도 진천군수이다.',
#   'subj': {'name': '유영훈', 'pos': [0, 3], 'type': 'PS'},
#   'obj': {'name': '충청북도', 'pos': [51, 55], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.5201705098152161},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '유영훈(劉永勳, 1955년 4월 30일 ~ )은 대한민국 기초단체장이자 제36·37·38대 충청북도 진천군수이다.',
#   'subj': {'name': '劉永勳', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '유영훈', 'pos': [0, 3], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8376585841178894},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '유영훈(劉永勳, 1955년 4월 30일 ~ )은 대한민국 기초단체장이자 제36·37·38대 충청북도 진천군수이다.',
#   'subj': {'name': '劉永勳', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '대한민국', 'pos': [27, 31], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5277253985404968},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '유영훈(劉永勳, 1955년 4월 30일 ~ )은 대한민국 기초단체장이자 제36·37·38대 충청북도 진천군수이다.',
#   'subj': {'name': '劉永勳', 'pos': [4, 7], 'type': 'PS'},
#   'obj': {'name': '충청북도', 'pos': [51, 55], 'type': 'LC'},
#   'description': '항목 주제가 태어난 장소',
#   'confidence': 0.571433961391449},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '뉘넌헤르번엔네데르베턴()은 네덜란드 노르트홀란트주의 도시로 면적은 33.94km, 높이는 16m, 인구는 22,567명(2014년 5월 기준), 인구 밀도는 669명/km이다.',
#   'subj': {'name': '뉘넌헤르번엔네데르베턴', 'pos': [0, 11], 'type': 'PS'},
#   'obj': {'name': '네덜란드', 'pos': [15, 19], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.9705318808555603},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '니우레케를란트()는 네덜란드 자위트홀란트주의 도시로 면적은 12.77km, 인구는 9,436명(2007년 1월 기준), 인구 밀도는 907명/km이다.',
#   'subj': {'name': '니우레케를란트', 'pos': [0, 7], 'type': 'LC'},
#   'obj': {'name': '자위트홀란트주', 'pos': [16, 23], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.822149932384491},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '니우레케를란트()는 네덜란드 자위트홀란트주의 도시로 면적은 12.77km, 인구는 9,436명(2007년 1월 기준), 인구 밀도는 907명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [11, 15], 'type': 'LC'},
#   'obj': {'name': '니우레케를란트', 'pos': [0, 7], 'type': 'LC'},
#   'description': '항목 주제인 지방 정부나 중앙 정부가 위치한 도시/자치도시',
#   'confidence': 0.5063400268554688},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '노르도스트폴더르()는 네덜란드 중부 플레볼란트주의 도시로 면적은 595.43km, 높이는 -3m, 인구는 46,450명(2014년 5월 기준), 인구 밀도는 101명/km이다.',
#   'subj': {'name': '노르도스트폴더르', 'pos': [0, 8], 'type': 'LC'},
#   'obj': {'name': '플레볼란트주', 'pos': [20, 26], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.8872790932655334},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '노르도스트폴더르()는 네덜란드 중부 플레볼란트주의 도시로 면적은 595.43km, 높이는 -3m, 인구는 46,450명(2014년 5월 기준), 인구 밀도는 101명/km이다.',
#   'subj': {'name': '네덜란드', 'pos': [12, 16], 'type': 'LC'},
#   'obj': {'name': '플레볼란트주', 'pos': [20, 26], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.9089625477790833},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '알레한드로 말도나도 아기레(, 1936년 1월 6일 ~ )는 과테말라의 정치인이다.',
#   'subj': {'name': '알레한드로 말도나도 아기레', 'pos': [0, 14], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [34, 38], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6867923140525818},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '과테말라시티에서 태어난 말도나도는 과테말라 산 카를로스 대학교에서 법학을 전공했다.',
#   'subj': {'name': '말도나도', 'pos': [13, 17], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [19, 23], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5976595282554626},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '아라나 오소리오', 'pos': [0, 8], 'type': 'PS'},
#   'obj': {'name': '루카스 가르시아 군사', 'pos': [46, 57], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.8428015112876892},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '아라나 오소리오', 'pos': [0, 8], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [115, 119], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5191774368286133},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '군사', 'pos': [9, 11], 'type': 'OG'},
#   'obj': {'name': '과테말라', 'pos': [115, 119], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7555381059646606},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '루카스 가르시아 군사', 'pos': [46, 57], 'type': 'PS'},
#   'obj': {'name': '아라나 오소리오', 'pos': [0, 8], 'type': 'PS'},
#   'description': '항목 주제의 전임자',
#   'confidence': 0.6115880012512207},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '루카스 가르시아 군사', 'pos': [46, 57], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [115, 119], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6665962338447571},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '가르시아', 'pos': [92, 96], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [115, 119], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.6343480944633484},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '아라나 오소리오 군사정권 (1970~1974년) 때에는 교육부장관을 역임하였으며, 루카스 가르시아 군사정권 (1978~1982년) 당시 인권 탄압 문제로 국제사회가 가르시아 정권을 고립시킬 때에는 유엔에서 과테말라를 대표하기도 했다.',
#   'subj': {'name': '유엔', 'pos': [110, 112], 'type': 'OG'},
#   'obj': {'name': '과테말라', 'pos': [115, 119], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8298952579498291},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1980년대 들어서 말도나도는 국가부활당이라는 당을 창당하여 1982년 총선에서 과테말라 기독민주당과 함께 연대를 꾸렸다.',
#   'subj': {'name': '국가부활당', 'pos': [17, 22], 'type': 'OG'},
#   'obj': {'name': '말도나도', 'pos': [11, 15], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7474783658981323},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1980년대 들어서 말도나도는 국가부활당이라는 당을 창당하여 1982년 총선에서 과테말라 기독민주당과 함께 연대를 꾸렸다.',
#   'subj': {'name': '국가부활당', 'pos': [17, 22], 'type': 'OG'},
#   'obj': {'name': '과테말라', 'pos': [45, 49], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.8766601085662842},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1980년대 들어서 말도나도는 국가부활당이라는 당을 창당하여 1982년 총선에서 과테말라 기독민주당과 함께 연대를 꾸렸다.',
#   'subj': {'name': '기독민주당', 'pos': [50, 55], 'type': 'OG'},
#   'obj': {'name': '말도나도', 'pos': [11, 15], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7624995112419128},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '2013년 5월에는 전 대통령 에프라인 리오스 몬트의 집단살해 혐의 공판을 맡게 되었다.',
#   'subj': {'name': '리오스 몬트', 'pos': [22, 28], 'type': 'PS'},
#   'obj': {'name': '에프라', 'pos': [17, 20], 'type': 'PS'},
#   'description': '항목 주제의 후임자',
#   'confidence': 0.5076098442077637},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1심에서 몬트에게 유죄를 내린 상태였는데 과테말라 헌법재판소의 전체 재판관 5인 중 말도나도와 나머지 두 재판관을 합친 3명이 최종 선고를 내리고 공판을 종료시키면서 큰 논란이 일었다.',
#   'subj': {'name': '몬트', 'pos': [5, 7], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [23, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.7068296074867249},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1심에서 몬트에게 유죄를 내린 상태였는데 과테말라 헌법재판소의 전체 재판관 5인 중 말도나도와 나머지 두 재판관을 합친 3명이 최종 선고를 내리고 공판을 종료시키면서 큰 논란이 일었다.',
#   'subj': {'name': '말도나도', 'pos': [47, 51], 'type': 'PS'},
#   'obj': {'name': '과테말라', 'pos': [23, 27], 'type': 'LC'},
#   'description': '항목 주제의 국가',
#   'confidence': 0.5816030502319336},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '동천역(東川驛)은 대한민국 경기도 용인시 수지구 동천동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '대한민국', 'pos': [10, 14], 'type': 'LC'},
#   'obj': {'name': '동천역', 'pos': [0, 3], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.5630630254745483},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '동천역(東川驛)은 대한민국 경기도 용인시 수지구 동천동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '대한민국', 'pos': [10, 14], 'type': 'LC'},
#   'obj': {'name': '東川驛', 'pos': [4, 7], 'type': 'LC'},
#   'description': '항목 주제인 경로가 끝나는 곳',
#   'confidence': 0.6220238208770752},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '수지구청역(水枝區廳驛)은 경기도 용인시 수지구 풍덕천로에 위치한 신분당선의 역으로, 계획 당시에는 풍덕천역이라는 가칭을 사용하였다가 2015년 9월 4일 국토교통부고시에 의하여 수지구청역으로 결정되었다.',
#   'subj': {'name': '경기도', 'pos': [14, 17], 'type': 'LC'},
#   'obj': {'name': '수지구청역', 'pos': [0, 5], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.5040395259857178},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '수지구청역(水枝區廳驛)은 경기도 용인시 수지구 풍덕천로에 위치한 신분당선의 역으로, 계획 당시에는 풍덕천역이라는 가칭을 사용하였다가 2015년 9월 4일 국토교통부고시에 의하여 수지구청역으로 결정되었다.',
#   'subj': {'name': '용인시', 'pos': [18, 21], 'type': 'LC'},
#   'obj': {'name': '수지구청역', 'pos': [0, 5], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.5578143000602722},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '수지구청역(水枝區廳驛)은 경기도 용인시 수지구 풍덕천로에 위치한 신분당선의 역으로, 계획 당시에는 풍덕천역이라는 가칭을 사용하였다가 2015년 9월 4일 국토교통부고시에 의하여 수지구청역으로 결정되었다.',
#   'subj': {'name': '수지구', 'pos': [22, 25], 'type': 'LC'},
#   'obj': {'name': '경기도', 'pos': [14, 17], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.6562932729721069},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '수지구청역(水枝區廳驛)은 경기도 용인시 수지구 풍덕천로에 위치한 신분당선의 역으로, 계획 당시에는 풍덕천역이라는 가칭을 사용하였다가 2015년 9월 4일 국토교통부고시에 의하여 수지구청역으로 결정되었다.',
#   'subj': {'name': '국토교통부', 'pos': [86, 91], 'type': 'OG'},
#   'obj': {'name': '경기도', 'pos': [14, 17], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5583508610725403},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '수지구청역(水枝區廳驛)은 경기도 용인시 수지구 풍덕천로에 위치한 신분당선의 역으로, 계획 당시에는 풍덕천역이라는 가칭을 사용하였다가 2015년 9월 4일 국토교통부고시에 의하여 수지구청역으로 결정되었다.',
#   'subj': {'name': '국토교통부', 'pos': [86, 91], 'type': 'OG'},
#   'obj': {'name': '용인시', 'pos': [18, 21], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5036662817001343},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '상현역(上峴驛)은 대한민국 경기도 용인시 수지구 상현동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '대한민국', 'pos': [10, 14], 'type': 'LC'},
#   'obj': {'name': '상현역', 'pos': [0, 3], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.7072142958641052},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '상현역(上峴驛)은 대한민국 경기도 용인시 수지구 상현동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '경기도', 'pos': [15, 18], 'type': 'LC'},
#   'obj': {'name': '상현역', 'pos': [0, 3], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.513552188873291},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '상현역(上峴驛)은 대한민국 경기도 용인시 수지구 상현동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '용인시', 'pos': [19, 22], 'type': 'LC'},
#   'obj': {'name': '상현역', 'pos': [0, 3], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.5534675717353821},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '계획 당시에는 신대역으로 불리었으나 용인시지명위원회는 2015년 2월 23일 이 역의 이름을 "상현역"또는 "상현광교역"으로 하기로 결정했고, 2015년 9월 4일 국토교통부고시에 의해 상현역으로 확정되었다.',
#   'subj': {'name': '상현역', 'pos': [53, 56], 'type': 'LC'},
#   'obj': {'name': '상현광교역', 'pos': [61, 66], 'type': 'LC'},
#   'description': '항목 주제인 경로가 끝나는 곳',
#   'confidence': 0.5225816965103149},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '광교중앙(아주대)역(光敎中央(亞洲大)驛)은 경기도 수원시 영통구 이의동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '아주대', 'pos': [5, 8], 'type': 'LC'},
#   'obj': {'name': '영통구', 'pos': [32, 35], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.6900397539138794},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '광교중앙(아주대)역(光敎中央(亞洲大)驛)은 경기도 수원시 영통구 이의동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '亞洲大', 'pos': [16, 19], 'type': 'LC'},
#   'obj': {'name': '光敎中央', 'pos': [11, 15], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.5972064137458801},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '광교중앙(아주대)역(光敎中央(亞洲大)驛)은 경기도 수원시 영통구 이의동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '亞洲大', 'pos': [16, 19], 'type': 'LC'},
#   'obj': {'name': '수원시', 'pos': [28, 31], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.632635235786438},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '광교중앙(아주대)역(光敎中央(亞洲大)驛)은 경기도 수원시 영통구 이의동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '亞洲大', 'pos': [16, 19], 'type': 'LC'},
#   'obj': {'name': '영통구', 'pos': [32, 35], 'type': 'LC'},
#   'description': '항목 주제가 위치한 지역',
#   'confidence': 0.8020523190498352},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '광교중앙(아주대)역(光敎中央(亞洲大)驛)은 경기도 수원시 영통구 이의동에 있는 신분당선의 전철역이다.',
#   'subj': {'name': '영통구', 'pos': [32, 35], 'type': 'LC'},
#   'obj': {'name': '경기도', 'pos': [24, 27], 'type': 'LC'},
#   'description': '항목 주제가 있거나 연결되어있는 지역',
#   'confidence': 0.5550076961517334},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '하행 선로는 광교차량사업소와 연결되어 있으며, 신분당선의 모든 열차는 이 역에서 차량기지 인입선을 통하여 회차한다.',
#   'subj': {'name': '광교차량사업소', 'pos': [7, 14], 'type': 'OG'},
#   'obj': {'name': '신분당선', 'pos': [26, 30], 'type': 'OG'},
#   'description': '항목 주제의 소유 조직',
#   'confidence': 0.9828777313232422},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '강남역과는 달리 이 역은 역 진입 전에 설치되어 있는 건넘선이 없기 때문에 정자, 강남 방면으로 돌아가기 위해서는 반드시 차량기지로 들어가야 회차하는 구조이다.',
#   'subj': {'name': '강남', 'pos': [46, 48], 'type': 'LC'},
#   'obj': {'name': '강남역', 'pos': [0, 3], 'type': 'LC'},
#   'description': '항목 주제인 경로가 시작되는 곳',
#   'confidence': 0.5925086140632629},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
# ...
#   'subj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'obj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7557588815689087},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'obj': {'name': '대동강', 'pos': [150, 153], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6750217080116272},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'obj': {'name': '大同江', 'pos': [154, 157], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6060519218444824},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '김부식', 'pos': [47, 50], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7340870499610901},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '金富軾', 'pos': [51, 54], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8347297310829163},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8119950294494629},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8062805533409119},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8504406809806824},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '대동강', 'pos': [150, 153], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.5659650564193726},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'obj': {'name': '大同江', 'pos': [154, 157], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.50726318359375},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '김부식', 'pos': [47, 50], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5825998187065125},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '金富軾', 'pos': [51, 54], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6934679746627808},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6346564888954163},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6430583000183105},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5283985137939453},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '대동강', 'pos': [150, 153], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7601748704910278},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'obj': {'name': '大同江', 'pos': [154, 157], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.715621292591095},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '김부식', 'pos': [47, 50], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6674411296844482},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '金富軾', 'pos': [51, 54], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7482295632362366},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '김양수', 'pos': [65, 68], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6557818651199341},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '金良秀', 'pos': [69, 72], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7332936525344849},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '권경량', 'pos': [113, 116], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7363703846931458},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '대동강', 'pos': [150, 153], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6104097366333008},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '1135년(인종 13) 묘청(妙淸)의 난 당시 합문지후(閤門祗候)로 있었는데, 원수 김부식(金富軾)의 명으로 대장군 김양수(金良秀)·시랑(侍郞) 양제보(楊齊寶)·원외랑(員外郞) 김정(金精)·직장(直長) 권경량(權景亮) 등과 함께 후군이 되어, 군사를 거느리고 요충지인 대동강(大同江)에 주둔했다.',
#   'subj': {'name': '權景亮', 'pos': [117, 120], 'type': 'PS'},
#   'obj': {'name': '大同江', 'pos': [154, 157], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.5485873222351074},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '서경', 'pos': [4, 6], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7402951121330261},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '西京', 'pos': [7, 9], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7582740783691406},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7315145134925842},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5265889167785645},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '이식', 'pos': [78, 80], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5577374696731567},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'obj': {'name': '李軾', 'pos': [81, 83], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8690459132194519},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '서경', 'pos': [4, 6], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.73948734998703},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '西京', 'pos': [7, 9], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.7365850210189819},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '김부식', 'pos': [29, 32], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5797164440155029},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.7371692657470703},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '이식', 'pos': [78, 80], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.6887102127075195},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'obj': {'name': '李軾', 'pos': [81, 83], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8922743797302246},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '서경', 'pos': [4, 6], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.6179783344268799},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '西京', 'pos': [7, 9], 'type': 'LC'},
#   'description': '항목 주제가 죽은 장소',
#   'confidence': 0.5983423590660095},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '이인실', 'pos': [60, 63], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.5041452050209045},
#  {'file_name': '/data/modified_KBN_data/wikipedia_0324.json',
#   'sentence': '이듬해 서경(西京)이 항복하여 난이 진압되자, 역시 김부식의 명을 받아 어사(御史)로서 어사잡단(御史雜端) 이인실(李仁實)·시어사(侍御史) 이식(李軾)과 함께 관부의 창고를 봉쇄했다.',
#   'subj': {'name': '李仁實', 'pos': [64, 67], 'type': 'PS'},
#   'obj': {'name': '李軾', 'pos': [81, 83], 'type': 'PS'},
#   'description': '항목 주제의 친척',
#   'confidence': 0.8051835894584656},
#  ...]

# %%
print(f"Total number of data: {len(total_data)}")
    

print('*'*35)
print(f"The number of train data: {len(train_data)}")
print(f"The number of dev data: {len(dev_data)}")
print(f"The number of test data: {len(test_data)}")
# Out:
# Total number of data: 4476095
# ***********************************
# The number of train data: 2685657
# The number of dev data: 895219
# The number of test data: 895219
